# %% [markdown]
# <a href="https://colab.research.google.com/github/cutberto-balderas/Think-Python/blob/main/chapters/chap06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py');
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py');

import thinkpython

# %% [markdown]
# # Return Values
#
# In previous chapters, we've used built-in functions -- like `abs` and `round` -- and functions in the math module -- like `sqrt` and `pow`.
# When you call one of these functions, it returns a value you can assign to a variable or use as part of an expression.
#
# The functions we have written so far are different.
# Some use the `print` function to display values, and some use turtle functions to draw figures.
# But they don't return values we assign to variables or use in expressions.
#
# In this chapter, we'll see how to write functions that return values.

# %% [markdown]
# ## Some functions have return values
#
# When you call a function like `math.sqrt`, the result is called a **return value**.
# If the function call appears at the end of a cell, Jupyter displays the return value immediately.

# %%
import math

math.sqrt(42 / math.pi)
# Out:
# 3.656366395715726

# %% [markdown]
# If you assign the return value to a variable, it doesn't get displayed.

# %%
radius = math.sqrt(42 / math.pi)

# %% [markdown]
# But you can display it later.

# %%
radius
# Out:
# 3.656366395715726

# %% [markdown]
# Or you can use the return value as part of an expression.

# %%
radius + math.sqrt(42 / math.pi)
# Out:
# 7.312732791431452

# %% [markdown]
# Here's an example of a function that returns a value.

# %%
def circle_area(radius):
    area = math.pi * radius**2
    return area

# %% [markdown]
# `circle_area` takes `radius` as a parameter and computes the area of a circle with that radius.
#
# The last line is a `return` statement that returns the value of `area`.
#
# If we call the function like this, Jupyter displays the return value.

# %%
circle_area(radius)
# Out:
# 42.00000000000001

# %% [markdown]
# We can assign the return value to a variable.

# %%
a = circle_area(radius)

# %% [markdown]
# Or use it as part of an expression.

# %%
circle_area(radius) + 2 * circle_area(radius / 2)
# Out:
# 63.000000000000014

# %% [markdown]
# Later we can display the value of the variable we assigned the result to.

# %%
a
# Out:
# 42.00000000000001

# %% [markdown]
# But we can't access `area`.

# %%
# %%expect NameError
#
# area
# Out:
# NameError: name 'area' is not defined

# %% [markdown]
# `area` is a local variable in a function, so we can't access it from outside the function.

# %% [markdown]
# ## And some have None
#
# If a function doesn't have a `return` statement, it returns `None`, which is a special value like `True` and `False`.
# For example, here's the `repeat` function from Chapter 3.

# %%
def repeat(word, n):
    print(word * n)

# %% [markdown]
# If we call it like this, it displays the first line of the Monty Python song "Finland".

# %%
repeat('Finland, ', 3)
# Out:
# Finland, Finland, Finland,

# %% [markdown]
# This function uses the `print` function to display a string, but it does not use a `return` statement to return a value.
# If we assign the result to a variable, it displays the string anyway.

# %%
result = repeat('Finland, ', 3)
# Out:
# Finland, Finland, Finland,

# %% [markdown]
# And if we display the value of the variable, we get nothing.

# %%
result

# %% [markdown]
# `result` actually has a value, but Jupyter doesn't show it.
# However, we can display it like this.

# %%
print(result)
# Out:
# None

# %% [markdown]
# The return value from `repeat` is `None`.
#
# Now here's a function similar to `repeat` except that has a return value.

# %%
def repeat_string(word, n):
    return word * n

# %% [markdown]
# Notice that we can use an expression in a `return` statement, not just a variable.
#
# With this version, we can assign the result to a variable.
# When the function runs, it doesn't display anything.

# %%
line = repeat_string('Spam, ', 4)

# %% [markdown]
# But later we can display the value assigned to `line`.

# %%
line
# Out:
# 'Spam, Spam, Spam, Spam, '

# %% [markdown]
# A function like this is called a **pure function** because it doesn't display anything or have any other effect -- other than returning a value.

# %% [markdown]
# ## Return values and conditionals
#
# If Python did not provide `abs`, we could write it like this.

# %%
def absolute_value(x):
    if x < 0:
        return -x
    else:
        return x

# %%
absolute_value(-1)
# Out:
# 1

# %% [markdown]
# If `x` is negative, the first `return` statement returns `-x` and the function ends immediately.
# Otherwise, the second `return` statement returns `x` and the function ends.
# So this function is correct.
#
# However, if you put `return` statements in a conditional, you have to make sure that every possible path through the program hits a `return` statement.
# For example, here's an incorrect version of `absolute_value`.

# %%
def absolute_value_wrong(x):
    if x < 0:
        return -x
    if x > 0:
        return x

# %% [markdown]
# Here's what happens if we call this function with `0` as an argument.

# %%
absolute_value_wrong(0)

# %% [markdown]
# We get nothing! Here's the problem: when `x` is `0`, neither condition is true, and the function ends without hitting a `return` statement, which means that the return value is `None`, so Jupyter displays nothing.
#
# As another example, here's a version of `absolute_value` with an extra `return` statement at the end.

# %%
def absolute_value_extra_return(x):
    if x < 0:
        return -x
    else:
        return x

    return 'This is dead code'

# %%
absolute_value_extra_return(-7)
# Out:
# 7

# %% [markdown]
# If `x` is negative, the first `return` statement runs and the function ends.
# Otherwise the second `return` statement runs and the function ends.
# Either way, we never get to the third `return` statement -- so it can never run.
#
# Code that can never run is called **dead code**.
# In general, dead code doesn't do any harm, but it often indicates a misunderstanding, and it might be confusing to someone trying to understand the program.

# %% [markdown]
# ## Incremental development
#
# As you write larger functions, you might find yourself spending more
# time debugging.
# To deal with increasingly complex programs, you might want to try **incremental development**, which is a way of adding and testing only a small amount of code at a time.
#
# As an example, suppose you want to find the distance between two points represented by the coordinates $(x_1, y_1)$ and $(x_2, y_2)$.
# By the Pythagorean theorem, the distance is:
#
# $$\mathrm{distance} = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}$$
#
# The first step is to consider what a `distance` function should look like in Python -- that is, what are the inputs (parameters) and what is the output (return value)?
#
# For this function, the inputs are the coordinates of the points.
# The return value is the distance.
# Immediately you can write an outline of the function:

# %%
def distance(x1, y1, x2, y2):
    return 0.0

# %% [markdown]
# This version doesn't compute distances yet -- it always returns zero.
# But it is a complete function with a return value, which means that you can test it before you make it more complicated.
#
# To test the new function, we'll call it with sample arguments:

# %%
distance(1, 2, 4, 6)
# Out:
# 0.0

# %% [markdown]
# I chose these values so that the horizontal distance is `3` and the
# vertical distance is `4`.
# That way, the result is `5`, the hypotenuse of a `3-4-5` right triangle. When testing a function, it is useful to know the right answer.
#
# At this point we have confirmed that the function runs and returns a value, and we can start adding code to the body.
# A good next step is to find the differences `x2 - x1` and `y2 - y1`.
# Here's a version that stores those values in temporary variables and displays them.

# %%
def distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    print('dx is', dx)
    print('dy is', dy)
    return 0.0

# %% [markdown]
# If the function is working, it should display `dx is 3` and `dy is 4`.
# If so, we know that the function is getting the right arguments and
# performing the first computation correctly. If not, there are only a few
# lines to check.

# %%
distance(1, 2, 4, 6)
# Out:
# dx is 3
# dy is 4
# 0.0

# %% [markdown]
# Good so far. Next we compute the sum of squares of `dx` and `dy`:

# %%
def distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    dsquared = dx**2 + dy**2
    print('dsquared is: ', dsquared)
    return 0.0

# %% [markdown]
# Again, we can run the function and check the output, which should be `25`.

# %%
distance(1, 2, 4, 6)
# Out:
# dsquared is:  25
# 0.0

# %% [markdown]
# Finally, we can use `math.sqrt` to compute the distance:

# %%
def distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    dsquared = dx**2 + dy**2
    result = math.sqrt(dsquared)
    print("result is", result)

# %% [markdown]
# And test it.

# %%
distance(1, 2, 4, 6)
# Out:
# result is 5.0

# %% [markdown]
# The result is correct, but this version of the function displays the result rather than returning it, so the return value is `None`.
#
# We can fix that by replacing the `print` function with a `return` statement.

# %%
def distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    dsquared = dx**2 + dy**2
    result = math.sqrt(dsquared)
    return result

# %% [markdown]
# This version of `distance` is a pure function.
# If we call it like this, only the result is displayed.

# %%
distance(1, 2, 4, 6)
# Out:
# 5.0

# %% [markdown]
# And if we assign the result to a variable, nothing is displayed.

# %%
d = distance(1, 2, 4, 6)

# %% [markdown]
# The `print` statements we wrote are useful for debugging, but once the function is working, we can remove them.
# Code like that is called **scaffolding** because it is helpful for building the program but is not part of the final product.
#
# This example demonstrates incremental development.
# The key aspects of this process are:
#
# 1.  Start with a working program, make small changes, and test after every change.
#
# 2.  Use variables to hold intermediate values so you can display and check them.
#
# 3.  Once the program is working, remove the scaffolding.
#
# At any point, if there is an error, you should have a good idea where it is.
# Incremental development can save you a lot of debugging time.

# %% [markdown]
# ## Boolean functions
#
# Functions can return the boolean values `True` and `False`, which is often convenient for encapsulating a complex test in a function.
# For example, `is_divisible` checks whether `x` is divisible by `y` with no remainder.

# %%
def is_divisible(x, y):
    if x % y == 0:
        return True
    else:
        return False

# %% [markdown]
# Here's how we use it.

# %%
is_divisible(6, 4)
# Out:
# False

# %%
is_divisible(6, 3)
# Out:
# True

# %% [markdown]
# Inside the function, the result of the `==` operator is a boolean, so we can write the
# function more concisely by returning it directly.

# %%
def is_divisible(x, y):
    return x % y == 0

# %% [markdown]
# Boolean functions are often used in conditional statements.

# %%
if is_divisible(6, 2):
    print('divisible')
# Out:
# divisible

# %% [markdown]
# It might be tempting to write something like this:

# %%
if is_divisible(6, 2) == True:
    print('divisible')
# Out:
# divisible

# %% [markdown]
# But the comparison is unnecessary.

# %% [markdown]
# ## Recursion with return values
#
# Now that we can write functions with return values, we can write recursive functions with return values, and with that capability, we have passed an important threshold -- the subset of Python we have is now **Turing complete**, which means that we can perform any computation that can be described by an algorithm.
#
# To demonstrate recursion with return values, we'll evaluate a few recursively defined mathematical functions.
# A recursive definition is similar to a circular definition, in the sense that the definition refers to the thing being defined. A truly circular definition is not very useful:
#
# > vorpal: An adjective used to describe something that is vorpal.
#
# If you saw that definition in the dictionary, you might be annoyed.
# On the other hand, if you looked up the definition of the factorial function, denoted with the symbol $!$, you might get something like this:
#
# $$\begin{aligned}
# 0! &= 1 \\
# n! &= n~(n-1)!
# \end{aligned}$$
#
# This definition says that the factorial of $0$ is $1$, and the factorial of any other value, $n$, is $n$ multiplied by the factorial of $n-1$.
#
# If you can write a recursive definition of something, you can write a Python program to evaluate it.
# Following an incremental development process, we'll start with a function that take `n` as a parameter and always returns `0`.

# %%
def factorial(n):
    return 0

# %%
factorial(1)
# Out:
# 0

# %% [markdown]
# Now let's add the first part of the definition -- if the argument happens to be `0`, all we have to do is return `1`:

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return 0

# %%
factorial(0)
# Out:
# 1

# %% [markdown]
# Now let's fill in the second part -- if `n` is not `0`, we have to make a recursive
# call to find the factorial of `n-1` and then multiply the result by `n`:

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        recurse = factorial(n-1)
        return n * recurse

# %%
factorial(10)
# Out:
# 3628800

# %% [markdown]
# The flow of execution for this program is similar to the flow of `countdown` in Chapter 5.
# If we call `factorial` with the value `3`:
#
# Since `3` is not `0`, we take the second branch and calculate the factorial
# of `n-1`\...
#
# > Since `2` is not `0`, we take the second branch and calculate the
# > factorial of `n-1`\...
# >
# > > Since `1` is not `0`, we take the second branch and calculate the
# > > factorial of `n-1`\...
# > >
# > > > Since `0` equals `0`, we take the first branch and return `1` without
# > > > making any more recursive calls.
# > >
# > > The return value, `1`, is multiplied by `n`, which is `1`, and the
# > > result is returned.
# >
# > The return value, `1`, is multiplied by `n`, which is `2`, and the result
# > is returned.
#
# The return value `2` is multiplied by `n`, which is `3`, and the result,
# `6`, becomes the return value of the function call that started the whole
# process.
#
# The following figure shows the stack diagram for this sequence of function calls.

# %%
from diagram import Frame, Stack, make_binding

main = Frame([], name='__main__', loc='left')
frames = [main]

ns = 3, 2, 1
recurses = 2, 1, 1
results = 6, 2, 1

for n, recurse, result in zip(ns, recurses, results):
    binding1 = make_binding('n', n)
    binding2 = make_binding('recurse', recurse)
    frame = Frame([binding1, binding2],
                  name='factorial', value=result,
                  loc='left', dx=1.2)
    frames.append(frame)

binding1 = make_binding('n', 0)
frame = Frame([binding1], name='factorial', value=1,
              shim=1.2, loc='left', dx=1.4)
frames.append(frame)

stack = Stack(frames, dy=-0.45)

# %%
from diagram import diagram, adjust

width, height, x, y = [2.74, 2.26, 0.73, 2.05]
ax = diagram(width, height)
bbox = stack.draw(ax, x, y)
# adjust(x, y, bbox)

# %% [markdown]
# The return values are shown being passed back up the stack.
# In each frame, the return value is the product of `n` and `recurse`.
#
# In the last frame, the local variable `recurse` does not exist because the branch that creates it does not run.

# %% [markdown]
# ## Leap of faith
#
# Following the flow of execution is one way to read programs, but it can quickly become overwhelming. An alternative is what I call the "leap of faith". When you come to a function call, instead of following the flow of execution, you *assume* that the function works correctly and returns the right result.
#
# In fact, you are already practicing this leap of faith when you use built-in functions.
# When you call `abs` or `math.sqrt`, you don't examine the bodies of those functions -- you just assume that they work.
#
# The same is true when you call one of your own functions. For example, earlier we wrote a function called `is_divisible` that determines whether one number is divisible by another. Once we convince ourselves that this function is correct, we can use it without looking at the body again.
#
# The same is true of recursive programs.
# When you get to the recursive call, instead of following the flow of execution, you should assume that the recursive call works and then ask yourself, "Assuming that I can compute the factorial of $n-1$, can I compute the factorial of $n$?"
# The recursive definition of factorial implies that you can, by multiplying by $n$.
#
# Of course, it's a bit strange to assume that the function works correctly when you haven't finished writing it, but that's why it's called a leap of faith!

# %% [markdown]
# ## Fibonacci
#
# After `factorial`, the most common example of a recursive function is `fibonacci`, which has the following definition:
#
# $$\begin{aligned}
# \mathrm{fibonacci}(0) &= 0 \\
# \mathrm{fibonacci}(1) &= 1 \\
# \mathrm{fibonacci}(n) &= \mathrm{fibonacci}(n-1) + \mathrm{fibonacci}(n-2)
# \end{aligned}$$
#
# Translated into Python, it looks like this:

# %%
def fibonacci(n):
    if n == 0:
        return 0
    elif  n == 1:
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)

# %% [markdown]
# If you try to follow the flow of execution here, even for small values of $n$, your head explodes.
# But according to the leap of faith, if you assume that the two recursive calls work correctly, you can be confident that the last `return` statement is correct.
#
# As an aside, this way of computing Fibonacci numbers is very inefficient.
# In [Chapter 10](section_memos) I'll explain why and suggest a way to improve it.

# %%
fibonacci(20)
# Out:
# 6765

# %% [markdown]
# ## Checking types
#
# What happens if we call `factorial` and give it `1.5` as an argument?

# %%
# %%expect RecursionError
#
# factorial(1.5)
# Out:
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# It looks like an infinite recursion. How can that be? The function has base cases when `n == 1` or `n == 0`.
# But if `n` is not an integer, we can *miss* the base case and recurse forever.
#
# In this example, the initial value of `n` is `1.5`.
# In the first recursive call, the value of `n` is `0.5`.
# In the next, it is `-0.5`.
# From there, it gets smaller (more negative), but it will never be `0`.
#
# To avoid infinite recursion we can use the built-in function `isinstance` to check the type of the argument.
# Here's how we check whether a value is an integer.

# %%
isinstance(3, int)
# Out:
# True

# %%
isinstance(1.5, int)
# Out:
# False

# %% [markdown]
# Now here's a version of `factorial` with error-checking.

# %%
def factorial(n):
    if not isinstance(n, int):
        print('factorial is only defined for integers.')
        return None
    elif n < 0:
        print('factorial is not defined for negative numbers.')
        return None
    elif n == 0:
        return 1
    else:
        return n * factorial(n-1)

# %% [markdown]
# First it checks whether `n` is an integer.
# If not, it displays an error message and returns `None`.

# %%
factorial('crunchy frog')
# Out:
# factorial is only defined for integers.

# %% [markdown]
# Then it checks whether `n` is negative.
# If so, it displays an error message and returns `None.`

# %%
factorial(-2)
# Out:
# factorial is not defined for negative numbers.

# %% [markdown]
# If we get past both checks, we know that `n` is a non-negative integer, so we can be confident the recursion will terminate.
# Checking the parameters of a function to make sure they have the correct types and values is called **input validation**.

# %% [markdown]
# ## Debugging
#
# Breaking a large program into smaller functions creates natural checkpoints for debugging.
# If a function is not working, there are three possibilities to consider:
#
# -   There is something wrong with the arguments the function is getting -- that is, a precondition is violated.
#
# -   There is something wrong with the function -- that is, a postcondition is violated.
#
# -   The caller is doing something wrong with the return value.
#
# To rule out the first possibility, you can add a `print` statement at the beginning of the function that displays the values of the parameters (and maybe their types).
# Or you can write code that checks the preconditions explicitly.
#
# If the parameters look good, you can add a `print` statement before each `return` statement and display the return value.
# If possible, call the function with arguments that make it easy check the result.
#
# If the function seems to be working, look at the function call to make sure the return value is being used correctly -- or used at all!
#
# Adding `print` statements at the beginning and end of a function can help make the flow of execution more visible.
# For example, here is a version of `factorial` with print statements:

# %%
def factorial(n):
    space = ' ' * (4 * n)
    print(space, 'factorial', n)
    if n == 0:
        print(space, 'returning 1')
        return 1
    else:
        recurse = factorial(n-1)
        result = n * recurse
        print(space, 'returning', result)
        return result

# %% [markdown]
# `space` is a string of space characters that controls the indentation of
# the output. Here is the result of `factorial(3)` :

# %%
factorial(10)
# Out:
#                                          factorial 10
#                                      factorial 9
#                                  factorial 8
#                              factorial 7
#                          factorial 6
#                      factorial 5
#                  factorial 4
#              factorial 3
#          factorial 2
#      factorial 1
#  factorial 0
#  returning 1
#      returning 1
#          returning 2
#              returning 6
#                  returning 24
#                      returning 120
#                          returning 720
#                              returning 5040
#                                  returning 40320
#                                      returning 362880
#                                          returning 3628800
# 3628800

# %% [markdown]
# If you are confused about the flow of execution, this kind of output can be helpful.
# It takes some time to develop effective scaffolding, but a little bit of scaffolding can save a lot of debugging.

# %% [markdown]
# ## Glossary
#
# **return value:**
# The result of a function. If a function call is used as an expression, the return value is the value of the expression.
#
# **pure function:**
# A function that does not display anything or have any other effect, other than returning a return value.
#
#
# **dead code:**
# Part of a program that can never run, often because it appears after a `return` statement.
#
# **incremental development:**
# A program development plan intended to avoid debugging by adding and testing only a small amount of code at a time.
#
# **scaffolding:**
#  Code that is used during program development but is not part of the final version.
#
# **Turing complete:**
# A language, or subset of a language, is Turing complete if it can perform any computation that can be described by an algorithm.
#
# **input validation:**
# Checking the parameters of a function to make sure they have the correct types and values

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %% [markdown]
# ### Ask a virtual assistant
#
# In this chapter, we saw an incorrect function that can end without returning a value.

# %%
def absolute_value_wrong(x):
    if x < 0:
        return -x
    if x > 0:
        return x

# %% [markdown]
# And a version of the same function that has dead code at the end.

# %%
def absolute_value_extra_return(x):
    if x < 0:
        return -x
    else:
        return x

    return 'This is dead code.'

# %% [markdown]
# And we saw the following example, which is correct but not idiomatic.

# %%
def is_divisible(x, y):
    if x % y == 0:
        return True
    else:
        return False

# %% [markdown]
# Here are the corrected versions:

# %%
def absolute_value_corrected(x):
    if x < 0:
        return -x
    else:
        # Handles x >= 0, including x == 0
        return x

print(f"Absolute value of -5: {absolute_value_corrected(-5)}")
print(f"Absolute value of 0: {absolute_value_corrected(0)}")
print(f"Absolute value of 5: {absolute_value_corrected(5)}")
# Out:
# Absolute value of -5: 5
# Absolute value of 0: 0
# Absolute value of 5: 5

# %%
def absolute_value_cleaned(x):
    if x < 0:
        return -x
    else:
        return x

print(f"Absolute value of -5: {absolute_value_cleaned(-5)}")
print(f"Absolute value of 0: {absolute_value_cleaned(0)}")
print(f"Absolute value of 5: {absolute_value_cleaned(5)}")
# Out:
# Absolute value of -5: 5
# Absolute value of 0: 0
# Absolute value of 5: 5

# %%
def is_divisible_idiomatic(x, y):
    return x % y == 0

print(f"Is 6 divisible by 3? {is_divisible_idiomatic(6, 3)}")
print(f"Is 7 divisible by 3? {is_divisible_idiomatic(7, 3)}")
# Out:
# Is 6 divisible by 3? True
# Is 7 divisible by 3? False

# %% [markdown]
# Ask a virtual assistant what's wrong with each of these functions and see if it can spot the errors or improve the style.
#
# Then ask "Write a function that takes coordinates of two points and computes the distance between them." See if the result resembles the version of `distance` we wrote in this chapter.

# %%
import math

def distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    dsquared = dx**2 + dy**2
    result = math.sqrt(dsquared)
    return result

# Example usage:
point1_x, point1_y = 1, 2
point2_x, point2_y = 4, 6
calculated_distance = distance(point1_x, point1_y, point2_x, point2_y)
print(f"The distance between ({point1_x}, {point1_y}) and ({point2_x}, {point2_y}) is: {calculated_distance}")
# Out:
# The distance between (1, 2) and (4, 6) is: 5.0

# %% [markdown]
# ### Exercise
#
# Use incremental development to write a function called `hypot` that returns the length of the hypotenuse of a right triangle given the lengths of the other two legs as arguments.
#
# Note: There's a function in the math module called `hypot` that does the same thing, but you should not use it for this exercise!
#
# Even if you can write the function correctly on the first try, start with a function that always returns `0` and practice making small changes, testing as you go.
# When you are done, the function should only return a value -- it should not display anything.

# %%
# Solution goes here

# I'll call the function 'hypotenuse' just to
# not have problems with the one already defined in math

def hypotenuse(a, b):
  """" Returns the length of the hypotenuse of a right triangle
  given the lengths of the other two sides.

  a and b are the lengths of the other two sides.
  """

  return 0

# %%
# Solution goes here

hypotenuse(3, 4)
# Out:
# The lengths of the sides are 3 and 4
# 0

# %%
# Solution goes here

def hypotenuse(a, b):
  """" Returns the length of the hypotenuse of a right triangle
  given the lengths of the other two sides.

  a and b are the lengths of the other two sides.
  """

  print("The lengths of the sides are", a, "and", b)
  return 0

# %%
# Solution goes here

hypotenuse(3, 4)
# Out:
# The lengths of the sides are 3 and 4
# 0

# %%
# Solution goes here
def hypotenuse(a, b):
  """" Returns the length of the hypotenuse of a right triangle
  given the lengths of the other two sides.

  a and b are the lengths of the other two sides.
  """

  c = math.sqrt(a**2 + b**2)
  print("The lengths of the sides are", a, "and", b)
  print("The length of the hypotenuse is", c)
  return 0

# %%
# Solution goes here

hypotenuse(3, 4)
# Out:
# The lengths of the sides are 3 and 4
# The length of the hypotenuse is 5.0
# 0

# %%
# Solution goes here

def hypotenuse(a, b):
  """" Returns the length of the hypotenuse of a right triangle
  given the lengths of the other two sides.

  a and b are the lengths of the other two sides.
  """

  c = math.sqrt(a**2 + b**2)
  return c

# %%
# Solution goes here

hypotenuse(3, 4)
# Out:
# 5.0

# %%
# Solution goes here

a = 3
b = 4

print("The length of the hypotenuse of a right triangle with sides", a, "and", b, "is", hypotenuse(a, b))
# Out:
# The length of the hypotenuse of a right triangle with sides 3 and 4 is 5.0

# %% [markdown]
# ### Exercise
#
# Write a boolean function, `is_between(x, y, z)`, that returns `True` if $x < y < z$ or if
# $z < y < x$, and`False` otherwise.

# %%
# Solution goes here

def is_between(x, y, z):
  return x < y < z or z < y < x

# %% [markdown]
# You can use these examples to test your function.

# %%
is_between(1, 2, 3)  # should be True
# Out:
# True

# %%
is_between(3, 2, 1)  # should be True
# Out:
# True

# %%
is_between(1, 3, 2)  # should be False
# Out:
# False

# %%
is_between(2, 3, 1)  # should be False
# Out:
# False

# %% [markdown]
# ### Exercise
#
# The Ackermann function, $A(m, n)$, is defined:
#
# $$\begin{aligned}
# A(m, n) = \begin{cases}
#               n+1 & \mbox{if } m = 0 \\
#         A(m-1, 1) & \mbox{if } m > 0 \mbox{ and } n = 0 \\
# A(m-1, A(m, n-1)) & \mbox{if } m > 0 \mbox{ and } n > 0.
# \end{cases}
# \end{aligned}$$
#
# Write a function named `ackermann` that evaluates the Ackermann function.
# What happens if you call `ackermann(5, 5)`?

# %%
# Solution goes here

def ackermann(m, n):
  """" Evaluates the Ackermann function.

  m and n are positive integers.
  """
  print(m, ",", n)
  if m == 0:
    print("m == 0")
    return n + 1
  elif m > 0 and n == 0:
    print("m > 0 and n == 0")
    return ackermann(m - 1, 1)
  else:
    print("m > 0 and n > 0")
    return ackermann(m - 1, ackermann(m, n - 1))

# %% [markdown]
# You can use these examples to test your function.

# %%
ackermann(3, 2)  # should be 29
# Out:
# 3 , 2
# m > 0 and n > 0
# 3 , 1
# m > 0 and n > 0
# 3 , 0
# m > 0 and n == 0
# 2 , 1
# m > 0 and n > 0
# 2 , 0
# m > 0 and n == 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 2 , 5
# m > 0 and n > 0
# 2 , 4
# m > 0 and n > 0
# 2 , 3
# m > 0 and n > 0
# 2 , 2
# m > 0 and n > 0
# 2 , 1
# m > 0 and n > 0
# 2 , 0
# m > 0 and n == 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 2 , 13
# m > 0 and n > 0
# 2 , 12
# m > 0 and n > 0
# 2 , 11
# m > 0 and n > 0
# 2 , 10
# m > 0 and n > 0
# 2 , 9
# m > 0 and n > 0
# 2 , 8
# m > 0 and n > 0
# 2 , 7
# m > 0 and n > 0
# 2 , 6
# m > 0 and n > 0
# 2 , 5
# m > 0 and n > 0
# 2 , 4
# m > 0 and n > 0
# 2 , 3
# m > 0 and n > 0
# 2 , 2
# m > 0 and n > 0
# 2 , 1
# m > 0 and n > 0
# 2 , 0
# m > 0 and n == 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 29

# %%
ackermann(3, 3)  # should be 61
# Out:
# 3 , 3
# m > 0 and n > 0
# 3 , 2
# m > 0 and n > 0
# 3 , 1
# m > 0 and n > 0
# 3 , 0
# m > 0 and n == 0
# 2 , 1
# m > 0 and n > 0
# 2 , 0
# m > 0 and n == 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 2 , 5
# m > 0 and n > 0
# 2 , 4
# m > 0 and n > 0
# 2 , 3
# m > 0 and n > 0
# 2 , 2
# m > 0 and n > 0
# 2 , 1
# m > 0 and n > 0
# 2 , 0
# m > 0 and n == 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 2 , 13
# m > 0 and n > 0
# 2 , 12
# m > 0 and n > 0
# 2 , 11
# m > 0 and n > 0
# 2 , 10
# m > 0 and n > 0
# 2 , 9
# m > 0 and n > 0
# 2 , 8
# m > 0 and n > 0
# 2 , 7
# m > 0 and n > 0
# 2 , 6
# m > 0 and n > 0
# 2 , 5
# m > 0 and n > 0
# 2 , 4
# m > 0 and n > 0
# 2 , 3
# m > 0 and n > 0
# 2 , 2
# m > 0 and n > 0
# 2 , 1
# m > 0 and n > 0
# 2 , 0
# m > 0 and n == 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 2 , 29
# m > 0 and n > 0
# 2 , 28
# m > 0 and n > 0
# 2 , 27
# m > 0 and n > 0
# 2 , 26
# m > 0 and n > 0
# 2 , 25
# m > 0 and n > 0
# 2 , 24
# m > 0 and n > 0
# 2 , 23
# m > 0 and n > 0
# 2 , 22
# m > 0 and n > 0
# 2 , 21
# m > 0 and n > 0
# 2 , 20
# m > 0 and n > 0
# 2 , 19
# m > 0 and n > 0
# 2 , 18
# m > 0 and n > 0
# 2 , 17
# m > 0 and n > 0
# 2 , 16
# m > 0 and n > 0
# 2 , 15
# m > 0 and n > 0
# 2 , 14
# m > 0 and n > 0
# 2 , 13
# m > 0 and n > 0
# 2 , 12
# m > 0 and n > 0
# 2 , 11
# m > 0 and n > 0
# 2 , 10
# m > 0 and n > 0
# 2 , 9
# m > 0 and n > 0
# 2 , 8
# m > 0 and n > 0
# 2 , 7
# m > 0 and n > 0
# 2 , 6
# m > 0 and n > 0
# 2 , 5
# m > 0 and n > 0
# 2 , 4
# m > 0 and n > 0
# 2 , 3
# m > 0 and n > 0
# 2 , 2
# m > 0 and n > 0
# 2 , 1
# m > 0 and n > 0
# 2 , 0
# m > 0 and n == 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 1 , 51
# m > 0 and n > 0
# 1 , 50
# m > 0 and n > 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 0 , 51
# m == 0
# 0 , 52
# m == 0
# 1 , 53
# m > 0 and n > 0
# 1 , 52
# m > 0 and n > 0
# 1 , 51
# m > 0 and n > 0
# 1 , 50
# m > 0 and n > 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 0 , 51
# m == 0
# 0 , 52
# m == 0
# 0 , 53
# m == 0
# 0 , 54
# m == 0
# 1 , 55
# m > 0 and n > 0
# 1 , 54
# m > 0 and n > 0
# 1 , 53
# m > 0 and n > 0
# 1 , 52
# m > 0 and n > 0
# 1 , 51
# m > 0 and n > 0
# 1 , 50
# m > 0 and n > 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 0 , 51
# m == 0
# 0 , 52
# m == 0
# 0 , 53
# m == 0
# 0 , 54
# m == 0
# 0 , 55
# m == 0
# 0 , 56
# m == 0
# 1 , 57
# m > 0 and n > 0
# 1 , 56
# m > 0 and n > 0
# 1 , 55
# m > 0 and n > 0
# 1 , 54
# m > 0 and n > 0
# 1 , 53
# m > 0 and n > 0
# 1 , 52
# m > 0 and n > 0
# 1 , 51
# m > 0 and n > 0
# 1 , 50
# m > 0 and n > 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 0 , 51
# m == 0
# 0 , 52
# m == 0
# 0 , 53
# m == 0
# 0 , 54
# m == 0
# 0 , 55
# m == 0
# 0 , 56
# m == 0
# 0 , 57
# m == 0
# 0 , 58
# m == 0
# 1 , 59
# m > 0 and n > 0
# 1 , 58
# m > 0 and n > 0
# 1 , 57
# m > 0 and n > 0
# 1 , 56
# m > 0 and n > 0
# 1 , 55
# m > 0 and n > 0
# 1 , 54
# m > 0 and n > 0
# 1 , 53
# m > 0 and n > 0
# 1 , 52
# m > 0 and n > 0
# 1 , 51
# m > 0 and n > 0
# 1 , 50
# m > 0 and n > 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 0 , 51
# m == 0
# 0 , 52
# m == 0
# 0 , 53
# m == 0
# 0 , 54
# m == 0
# 0 , 55
# m == 0
# 0 , 56
# m == 0
# 0 , 57
# m == 0
# 0 , 58
# m == 0
# 0 , 59
# m == 0
# 0 , 60
# m == 0
# 61

# %%
ackermann(3, 4)  # should be 125
# Out:
# 3 , 4
# m > 0 and n > 0
# 3 , 3
# m > 0 and n > 0
# 3 , 2
# m > 0 and n > 0
# 3 , 1
# m > 0 and n > 0
# 3 , 0
# m > 0 and n == 0
# 2 , 1
# m > 0 and n > 0
# 2 , 0
# m > 0 and n == 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 2 , 5
# m > 0 and n > 0
# 2 , 4
# m > 0 and n > 0
# 2 , 3
# m > 0 and n > 0
# 2 , 2
# m > 0 and n > 0
# 2 , 1
# m > 0 and n > 0
# 2 , 0
# m > 0 and n == 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 2 , 13
# m > 0 and n > 0
# 2 , 12
# m > 0 and n > 0
# 2 , 11
# m > 0 and n > 0
# 2 , 10
# m > 0 and n > 0
# 2 , 9
# m > 0 and n > 0
# 2 , 8
# m > 0 and n > 0
# 2 , 7
# m > 0 and n > 0
# 2 , 6
# m > 0 and n > 0
# 2 , 5
# m > 0 and n > 0
# 2 , 4
# m > 0 and n > 0
# 2 , 3
# m > 0 and n > 0
# 2 , 2
# m > 0 and n > 0
# 2 , 1
# m > 0 and n > 0
# 2 , 0
# m > 0 and n == 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 2 , 29
# m > 0 and n > 0
# 2 , 28
# m > 0 and n > 0
# 2 , 27
# m > 0 and n > 0
# 2 , 26
# m > 0 and n > 0
# 2 , 25
# m > 0 and n > 0
# 2 , 24
# m > 0 and n > 0
# 2 , 23
# m > 0 and n > 0
# 2 , 22
# m > 0 and n > 0
# 2 , 21
# m > 0 and n > 0
# 2 , 20
# m > 0 and n > 0
# 2 , 19
# m > 0 and n > 0
# 2 , 18
# m > 0 and n > 0
# 2 , 17
# m > 0 and n > 0
# 2 , 16
# m > 0 and n > 0
# 2 , 15
# m > 0 and n > 0
# 2 , 14
# m > 0 and n > 0
# 2 , 13
# m > 0 and n > 0
# 2 , 12
# m > 0 and n > 0
# 2 , 11
# m > 0 and n > 0
# 2 , 10
# m > 0 and n > 0
# 2 , 9
# m > 0 and n > 0
# 2 , 8
# m > 0 and n > 0
# 2 , 7
# m > 0 and n > 0
# 2 , 6
# m > 0 and n > 0
# 2 , 5
# m > 0 and n > 0
# 2 , 4
# m > 0 and n > 0
# 2 , 3
# m > 0 and n > 0
# 2 , 2
# m > 0 and n > 0
# 2 , 1
# m > 0 and n > 0
# 2 , 0
# m > 0 and n == 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 1 , 51
# m > 0 and n > 0
# 1 , 50
# m > 0 and n > 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 0 , 51
# m == 0
# 0 , 52
# m == 0
# 1 , 53
# m > 0 and n > 0
# 1 , 52
# m > 0 and n > 0
# 1 , 51
# m > 0 and n > 0
# 1 , 50
# m > 0 and n > 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 0 , 51
# m == 0
# 0 , 52
# m == 0
# 0 , 53
# m == 0
# 0 , 54
# m == 0
# 1 , 55
# m > 0 and n > 0
# 1 , 54
# m > 0 and n > 0
# 1 , 53
# m > 0 and n > 0
# 1 , 52
# m > 0 and n > 0
# 1 , 51
# m > 0 and n > 0
# 1 , 50
# m > 0 and n > 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 0 , 51
# m == 0
# 0 , 52
# m == 0
# 0 , 53
# m == 0
# 0 , 54
# m == 0
# 0 , 55
# m == 0
# 0 , 56
# m == 0
# 1 , 57
# m > 0 and n > 0
# 1 , 56
# m > 0 and n > 0
# 1 , 55
# m > 0 and n > 0
# 1 , 54
# m > 0 and n > 0
# 1 , 53
# m > 0 and n > 0
# 1 , 52
# m > 0 and n > 0
# 1 , 51
# m > 0 and n > 0
# 1 , 50
# m > 0 and n > 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 0 , 51
# m == 0
# 0 , 52
# m == 0
# 0 , 53
# m == 0
# 0 , 54
# m == 0
# 0 , 55
# m == 0
# 0 , 56
# m == 0
# 0 , 57
# m == 0
# 0 , 58
# m == 0
# 1 , 59
# m > 0 and n > 0
# 1 , 58
# m > 0 and n > 0
# 1 , 57
# m > 0 and n > 0
# 1 , 56
# m > 0 and n > 0
# 1 , 55
# m > 0 and n > 0
# 1 , 54
# m > 0 and n > 0
# 1 , 53
# m > 0 and n > 0
# 1 , 52
# m > 0 and n > 0
# 1 , 51
# m > 0 and n > 0
# 1 , 50
# m > 0 and n > 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 0 , 51
# m == 0
# 0 , 52
# m == 0
# 0 , 53
# m == 0
# 0 , 54
# m == 0
# 0 , 55
# m == 0
# 0 , 56
# m == 0
# 0 , 57
# m == 0
# 0 , 58
# m == 0
# 0 , 59
# m == 0
# 0 , 60
# m == 0
# 2 , 61
# m > 0 and n > 0
# 2 , 60
# m > 0 and n > 0
# 2 , 59
# m > 0 and n > 0
# 2 , 58
# m > 0 and n > 0
# 2 , 57
# m > 0 and n > 0
# 2 , 56
# m > 0 and n > 0
# 2 , 55
# m > 0 and n > 0
# 2 , 54
# m > 0 and n > 0
# 2 , 53
# m > 0 and n > 0
# 2 , 52
# m > 0 and n > 0
# 2 , 51
# m > 0 and n > 0
# 2 , 50
# m > 0 and n > 0
# 2 , 49
# m > 0 and n > 0
# 2 , 48
# m > 0 and n > 0
# 2 , 47
# m > 0 and n > 0
# 2 , 46
# m > 0 and n > 0
# 2 , 45
# m > 0 and n > 0
# 2 , 44
# m > 0 and n > 0
# 2 , 43
# m > 0 and n > 0
# 2 , 42
# m > 0 and n > 0
# 2 , 41
# m > 0 and n > 0
# 2 , 40
# m > 0 and n > 0
# 2 , 39
# m > 0 and n > 0
# 2 , 38
# m > 0 and n > 0
# 2 , 37
# m > 0 and n > 0
# 2 , 36
# m > 0 and n > 0
# 2 , 35
# m > 0 and n > 0
# 2 , 34
# m > 0 and n > 0
# 2 , 33
# m > 0 and n > 0
# 2 , 32
# m > 0 and n > 0
# 2 , 31
# m > 0 and n > 0
# 2 , 30
# m > 0 and n > 0
# 2 , 29
# m > 0 and n > 0
# 2 , 28
# m > 0 and n > 0
# 2 , 27
# m > 0 and n > 0
# 2 , 26
# m > 0 and n > 0
# 2 , 25
# m > 0 and n > 0
# 2 , 24
# m > 0 and n > 0
# 2 , 23
# m > 0 and n > 0
# 2 , 22
# m > 0 and n > 0
# 2 , 21
# m > 0 and n > 0
# 2 , 20
# m > 0 and n > 0
# 2 , 19
# m > 0 and n > 0
# 2 , 18
# m > 0 and n > 0
# 2 , 17
# m > 0 and n > 0
# 2 , 16
# m > 0 and n > 0
# 2 , 15
# m > 0 and n > 0
# 2 , 14
# m > 0 and n > 0
# 2 , 13
# m > 0 and n > 0
# 2 , 12
# m > 0 and n > 0
# 2 , 11
# m > 0 and n > 0
# 2 , 10
# m > 0 and n > 0
# 2 , 9
# m > 0 and n > 0
# 2 , 8
# m > 0 and n > 0
# 2 , 7
# m > 0 and n > 0
# 2 , 6
# m > 0 and n > 0
# 2 , 5
# m > 0 and n > 0
# 2 , 4
# m > 0 and n > 0
# 2 , 3
# m > 0 and n > 0
# 2 , 2
# m > 0 and n > 0
# 2 , 1
# m > 0 and n > 0
# 2 , 0
# m > 0 and n == 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# ...
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 0 , 51
# m == 0
# 0 , 52
# m == 0
# 0 , 53
# m == 0
# 0 , 54
# m == 0
# 0 , 55
# m == 0
# 0 , 56
# m == 0
# 0 , 57
# m == 0
# 0 , 58
# m == 0
# 0 , 59
# m == 0
# 0 , 60
# m == 0
# 0 , 61
# m == 0
# 0 , 62
# m == 0
# 0 , 63
# m == 0
# 0 , 64
# m == 0
# 0 , 65
# m == 0
# 0 , 66
# m == 0
# 0 , 67
# m == 0
# 0 , 68
# m == 0
# 0 , 69
# m == 0
# 0 , 70
# m == 0
# 0 , 71
# m == 0
# 0 , 72
# m == 0
# 0 , 73
# m == 0
# 0 , 74
# m == 0
# 0 , 75
# m == 0
# 0 , 76
# m == 0
# 0 , 77
# m == 0
# 0 , 78
# m == 0
# 0 , 79
# m == 0
# 0 , 80
# m == 0
# 0 , 81
# m == 0
# 0 , 82
# m == 0
# 0 , 83
# m == 0
# 0 , 84
# m == 0
# 0 , 85
# m == 0
# 0 , 86
# m == 0
# 0 , 87
# m == 0
# 0 , 88
# m == 0
# 0 , 89
# m == 0
# 0 , 90
# m == 0
# 0 , 91
# m == 0
# 0 , 92
# m == 0
# 0 , 93
# m == 0
# 0 , 94
# m == 0
# 0 , 95
# m == 0
# 0 , 96
# m == 0
# 0 , 97
# m == 0
# 0 , 98
# m == 0
# 0 , 99
# m == 0
# 0 , 100
# m == 0
# 0 , 101
# m == 0
# 0 , 102
# m == 0
# 0 , 103
# m == 0
# 0 , 104
# m == 0
# 0 , 105
# m == 0
# 0 , 106
# m == 0
# 0 , 107
# m == 0
# 0 , 108
# m == 0
# 0 , 109
# m == 0
# 0 , 110
# m == 0
# 0 , 111
# m == 0
# 0 , 112
# m == 0
# 0 , 113
# m == 0
# 0 , 114
# m == 0
# 0 , 115
# m == 0
# 0 , 116
# m == 0
# 0 , 117
# m == 0
# 0 , 118
# m == 0
# 1 , 119
# m > 0 and n > 0
# 1 , 118
# m > 0 and n > 0
# 1 , 117
# m > 0 and n > 0
# 1 , 116
# m > 0 and n > 0
# 1 , 115
# m > 0 and n > 0
# 1 , 114
# m > 0 and n > 0
# 1 , 113
# m > 0 and n > 0
# 1 , 112
# m > 0 and n > 0
# 1 , 111
# m > 0 and n > 0
# 1 , 110
# m > 0 and n > 0
# 1 , 109
# m > 0 and n > 0
# 1 , 108
# m > 0 and n > 0
# 1 , 107
# m > 0 and n > 0
# 1 , 106
# m > 0 and n > 0
# 1 , 105
# m > 0 and n > 0
# 1 , 104
# m > 0 and n > 0
# 1 , 103
# m > 0 and n > 0
# 1 , 102
# m > 0 and n > 0
# 1 , 101
# m > 0 and n > 0
# 1 , 100
# m > 0 and n > 0
# 1 , 99
# m > 0 and n > 0
# 1 , 98
# m > 0 and n > 0
# 1 , 97
# m > 0 and n > 0
# 1 , 96
# m > 0 and n > 0
# 1 , 95
# m > 0 and n > 0
# 1 , 94
# m > 0 and n > 0
# 1 , 93
# m > 0 and n > 0
# 1 , 92
# m > 0 and n > 0
# 1 , 91
# m > 0 and n > 0
# 1 , 90
# m > 0 and n > 0
# 1 , 89
# m > 0 and n > 0
# 1 , 88
# m > 0 and n > 0
# 1 , 87
# m > 0 and n > 0
# 1 , 86
# m > 0 and n > 0
# 1 , 85
# m > 0 and n > 0
# 1 , 84
# m > 0 and n > 0
# 1 , 83
# m > 0 and n > 0
# 1 , 82
# m > 0 and n > 0
# 1 , 81
# m > 0 and n > 0
# 1 , 80
# m > 0 and n > 0
# 1 , 79
# m > 0 and n > 0
# 1 , 78
# m > 0 and n > 0
# 1 , 77
# m > 0 and n > 0
# 1 , 76
# m > 0 and n > 0
# 1 , 75
# m > 0 and n > 0
# 1 , 74
# m > 0 and n > 0
# 1 , 73
# m > 0 and n > 0
# 1 , 72
# m > 0 and n > 0
# 1 , 71
# m > 0 and n > 0
# 1 , 70
# m > 0 and n > 0
# 1 , 69
# m > 0 and n > 0
# 1 , 68
# m > 0 and n > 0
# 1 , 67
# m > 0 and n > 0
# 1 , 66
# m > 0 and n > 0
# 1 , 65
# m > 0 and n > 0
# 1 , 64
# m > 0 and n > 0
# 1 , 63
# m > 0 and n > 0
# 1 , 62
# m > 0 and n > 0
# 1 , 61
# m > 0 and n > 0
# 1 , 60
# m > 0 and n > 0
# 1 , 59
# m > 0 and n > 0
# 1 , 58
# m > 0 and n > 0
# 1 , 57
# m > 0 and n > 0
# 1 , 56
# m > 0 and n > 0
# 1 , 55
# m > 0 and n > 0
# 1 , 54
# m > 0 and n > 0
# 1 , 53
# m > 0 and n > 0
# 1 , 52
# m > 0 and n > 0
# 1 , 51
# m > 0 and n > 0
# 1 , 50
# m > 0 and n > 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 0 , 51
# m == 0
# 0 , 52
# m == 0
# 0 , 53
# m == 0
# 0 , 54
# m == 0
# 0 , 55
# m == 0
# 0 , 56
# m == 0
# 0 , 57
# m == 0
# 0 , 58
# m == 0
# 0 , 59
# m == 0
# 0 , 60
# m == 0
# 0 , 61
# m == 0
# 0 , 62
# m == 0
# 0 , 63
# m == 0
# 0 , 64
# m == 0
# 0 , 65
# m == 0
# 0 , 66
# m == 0
# 0 , 67
# m == 0
# 0 , 68
# m == 0
# 0 , 69
# m == 0
# 0 , 70
# m == 0
# 0 , 71
# m == 0
# 0 , 72
# m == 0
# 0 , 73
# m == 0
# 0 , 74
# m == 0
# 0 , 75
# m == 0
# 0 , 76
# m == 0
# 0 , 77
# m == 0
# 0 , 78
# m == 0
# 0 , 79
# m == 0
# 0 , 80
# m == 0
# 0 , 81
# m == 0
# 0 , 82
# m == 0
# 0 , 83
# m == 0
# 0 , 84
# m == 0
# 0 , 85
# m == 0
# 0 , 86
# m == 0
# 0 , 87
# m == 0
# 0 , 88
# m == 0
# 0 , 89
# m == 0
# 0 , 90
# m == 0
# 0 , 91
# m == 0
# 0 , 92
# m == 0
# 0 , 93
# m == 0
# 0 , 94
# m == 0
# 0 , 95
# m == 0
# 0 , 96
# m == 0
# 0 , 97
# m == 0
# 0 , 98
# m == 0
# 0 , 99
# m == 0
# 0 , 100
# m == 0
# 0 , 101
# m == 0
# 0 , 102
# m == 0
# 0 , 103
# m == 0
# 0 , 104
# m == 0
# 0 , 105
# m == 0
# 0 , 106
# m == 0
# 0 , 107
# m == 0
# 0 , 108
# m == 0
# 0 , 109
# m == 0
# 0 , 110
# m == 0
# 0 , 111
# m == 0
# 0 , 112
# m == 0
# 0 , 113
# m == 0
# 0 , 114
# m == 0
# 0 , 115
# m == 0
# 0 , 116
# m == 0
# 0 , 117
# m == 0
# 0 , 118
# m == 0
# 0 , 119
# m == 0
# 0 , 120
# m == 0
# 1 , 121
# m > 0 and n > 0
# 1 , 120
# m > 0 and n > 0
# 1 , 119
# m > 0 and n > 0
# 1 , 118
# m > 0 and n > 0
# 1 , 117
# m > 0 and n > 0
# 1 , 116
# m > 0 and n > 0
# 1 , 115
# m > 0 and n > 0
# 1 , 114
# m > 0 and n > 0
# 1 , 113
# m > 0 and n > 0
# 1 , 112
# m > 0 and n > 0
# 1 , 111
# m > 0 and n > 0
# 1 , 110
# m > 0 and n > 0
# 1 , 109
# m > 0 and n > 0
# 1 , 108
# m > 0 and n > 0
# 1 , 107
# m > 0 and n > 0
# 1 , 106
# m > 0 and n > 0
# 1 , 105
# m > 0 and n > 0
# 1 , 104
# m > 0 and n > 0
# 1 , 103
# m > 0 and n > 0
# 1 , 102
# m > 0 and n > 0
# 1 , 101
# m > 0 and n > 0
# 1 , 100
# m > 0 and n > 0
# 1 , 99
# m > 0 and n > 0
# 1 , 98
# m > 0 and n > 0
# 1 , 97
# m > 0 and n > 0
# 1 , 96
# m > 0 and n > 0
# 1 , 95
# m > 0 and n > 0
# 1 , 94
# m > 0 and n > 0
# 1 , 93
# m > 0 and n > 0
# 1 , 92
# m > 0 and n > 0
# 1 , 91
# m > 0 and n > 0
# 1 , 90
# m > 0 and n > 0
# 1 , 89
# m > 0 and n > 0
# 1 , 88
# m > 0 and n > 0
# 1 , 87
# m > 0 and n > 0
# 1 , 86
# m > 0 and n > 0
# 1 , 85
# m > 0 and n > 0
# 1 , 84
# m > 0 and n > 0
# 1 , 83
# m > 0 and n > 0
# 1 , 82
# m > 0 and n > 0
# 1 , 81
# m > 0 and n > 0
# 1 , 80
# m > 0 and n > 0
# 1 , 79
# m > 0 and n > 0
# 1 , 78
# m > 0 and n > 0
# 1 , 77
# m > 0 and n > 0
# 1 , 76
# m > 0 and n > 0
# 1 , 75
# m > 0 and n > 0
# 1 , 74
# m > 0 and n > 0
# 1 , 73
# m > 0 and n > 0
# 1 , 72
# m > 0 and n > 0
# 1 , 71
# m > 0 and n > 0
# 1 , 70
# m > 0 and n > 0
# 1 , 69
# m > 0 and n > 0
# 1 , 68
# m > 0 and n > 0
# 1 , 67
# m > 0 and n > 0
# 1 , 66
# m > 0 and n > 0
# 1 , 65
# m > 0 and n > 0
# 1 , 64
# m > 0 and n > 0
# 1 , 63
# m > 0 and n > 0
# 1 , 62
# m > 0 and n > 0
# 1 , 61
# m > 0 and n > 0
# 1 , 60
# m > 0 and n > 0
# 1 , 59
# m > 0 and n > 0
# 1 , 58
# m > 0 and n > 0
# 1 , 57
# m > 0 and n > 0
# 1 , 56
# m > 0 and n > 0
# 1 , 55
# m > 0 and n > 0
# 1 , 54
# m > 0 and n > 0
# 1 , 53
# m > 0 and n > 0
# 1 , 52
# m > 0 and n > 0
# 1 , 51
# m > 0 and n > 0
# 1 , 50
# m > 0 and n > 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 0 , 51
# m == 0
# 0 , 52
# m == 0
# 0 , 53
# m == 0
# 0 , 54
# m == 0
# 0 , 55
# m == 0
# 0 , 56
# m == 0
# 0 , 57
# m == 0
# 0 , 58
# m == 0
# 0 , 59
# m == 0
# 0 , 60
# m == 0
# 0 , 61
# m == 0
# 0 , 62
# m == 0
# 0 , 63
# m == 0
# 0 , 64
# m == 0
# 0 , 65
# m == 0
# 0 , 66
# m == 0
# 0 , 67
# m == 0
# 0 , 68
# m == 0
# 0 , 69
# m == 0
# 0 , 70
# m == 0
# 0 , 71
# m == 0
# 0 , 72
# m == 0
# 0 , 73
# m == 0
# 0 , 74
# m == 0
# 0 , 75
# m == 0
# 0 , 76
# m == 0
# 0 , 77
# m == 0
# 0 , 78
# m == 0
# 0 , 79
# m == 0
# 0 , 80
# m == 0
# 0 , 81
# m == 0
# 0 , 82
# m == 0
# 0 , 83
# m == 0
# 0 , 84
# m == 0
# 0 , 85
# m == 0
# 0 , 86
# m == 0
# 0 , 87
# m == 0
# 0 , 88
# m == 0
# 0 , 89
# m == 0
# 0 , 90
# m == 0
# 0 , 91
# m == 0
# 0 , 92
# m == 0
# 0 , 93
# m == 0
# 0 , 94
# m == 0
# 0 , 95
# m == 0
# 0 , 96
# m == 0
# 0 , 97
# m == 0
# 0 , 98
# m == 0
# 0 , 99
# m == 0
# 0 , 100
# m == 0
# 0 , 101
# m == 0
# 0 , 102
# m == 0
# 0 , 103
# m == 0
# 0 , 104
# m == 0
# 0 , 105
# m == 0
# 0 , 106
# m == 0
# 0 , 107
# m == 0
# 0 , 108
# m == 0
# 0 , 109
# m == 0
# 0 , 110
# m == 0
# 0 , 111
# m == 0
# 0 , 112
# m == 0
# 0 , 113
# m == 0
# 0 , 114
# m == 0
# 0 , 115
# m == 0
# 0 , 116
# m == 0
# 0 , 117
# m == 0
# 0 , 118
# m == 0
# 0 , 119
# m == 0
# 0 , 120
# m == 0
# 0 , 121
# m == 0
# 0 , 122
# m == 0
# 1 , 123
# m > 0 and n > 0
# 1 , 122
# m > 0 and n > 0
# 1 , 121
# m > 0 and n > 0
# 1 , 120
# m > 0 and n > 0
# 1 , 119
# m > 0 and n > 0
# 1 , 118
# m > 0 and n > 0
# 1 , 117
# m > 0 and n > 0
# 1 , 116
# m > 0 and n > 0
# 1 , 115
# m > 0 and n > 0
# 1 , 114
# m > 0 and n > 0
# 1 , 113
# m > 0 and n > 0
# 1 , 112
# m > 0 and n > 0
# 1 , 111
# m > 0 and n > 0
# 1 , 110
# m > 0 and n > 0
# 1 , 109
# m > 0 and n > 0
# 1 , 108
# m > 0 and n > 0
# 1 , 107
# m > 0 and n > 0
# 1 , 106
# m > 0 and n > 0
# 1 , 105
# m > 0 and n > 0
# 1 , 104
# m > 0 and n > 0
# 1 , 103
# m > 0 and n > 0
# 1 , 102
# m > 0 and n > 0
# 1 , 101
# m > 0 and n > 0
# 1 , 100
# m > 0 and n > 0
# 1 , 99
# m > 0 and n > 0
# 1 , 98
# m > 0 and n > 0
# 1 , 97
# m > 0 and n > 0
# 1 , 96
# m > 0 and n > 0
# 1 , 95
# m > 0 and n > 0
# 1 , 94
# m > 0 and n > 0
# 1 , 93
# m > 0 and n > 0
# 1 , 92
# m > 0 and n > 0
# 1 , 91
# m > 0 and n > 0
# 1 , 90
# m > 0 and n > 0
# 1 , 89
# m > 0 and n > 0
# 1 , 88
# m > 0 and n > 0
# 1 , 87
# m > 0 and n > 0
# 1 , 86
# m > 0 and n > 0
# 1 , 85
# m > 0 and n > 0
# 1 , 84
# m > 0 and n > 0
# 1 , 83
# m > 0 and n > 0
# 1 , 82
# m > 0 and n > 0
# 1 , 81
# m > 0 and n > 0
# 1 , 80
# m > 0 and n > 0
# 1 , 79
# m > 0 and n > 0
# 1 , 78
# m > 0 and n > 0
# 1 , 77
# m > 0 and n > 0
# 1 , 76
# m > 0 and n > 0
# 1 , 75
# m > 0 and n > 0
# 1 , 74
# m > 0 and n > 0
# 1 , 73
# m > 0 and n > 0
# 1 , 72
# m > 0 and n > 0
# 1 , 71
# m > 0 and n > 0
# 1 , 70
# m > 0 and n > 0
# 1 , 69
# m > 0 and n > 0
# 1 , 68
# m > 0 and n > 0
# 1 , 67
# m > 0 and n > 0
# 1 , 66
# m > 0 and n > 0
# 1 , 65
# m > 0 and n > 0
# 1 , 64
# m > 0 and n > 0
# 1 , 63
# m > 0 and n > 0
# 1 , 62
# m > 0 and n > 0
# 1 , 61
# m > 0 and n > 0
# 1 , 60
# m > 0 and n > 0
# 1 , 59
# m > 0 and n > 0
# 1 , 58
# m > 0 and n > 0
# 1 , 57
# m > 0 and n > 0
# 1 , 56
# m > 0 and n > 0
# 1 , 55
# m > 0 and n > 0
# 1 , 54
# m > 0 and n > 0
# 1 , 53
# m > 0 and n > 0
# 1 , 52
# m > 0 and n > 0
# 1 , 51
# m > 0 and n > 0
# 1 , 50
# m > 0 and n > 0
# 1 , 49
# m > 0 and n > 0
# 1 , 48
# m > 0 and n > 0
# 1 , 47
# m > 0 and n > 0
# 1 , 46
# m > 0 and n > 0
# 1 , 45
# m > 0 and n > 0
# 1 , 44
# m > 0 and n > 0
# 1 , 43
# m > 0 and n > 0
# 1 , 42
# m > 0 and n > 0
# 1 , 41
# m > 0 and n > 0
# 1 , 40
# m > 0 and n > 0
# 1 , 39
# m > 0 and n > 0
# 1 , 38
# m > 0 and n > 0
# 1 , 37
# m > 0 and n > 0
# 1 , 36
# m > 0 and n > 0
# 1 , 35
# m > 0 and n > 0
# 1 , 34
# m > 0 and n > 0
# 1 , 33
# m > 0 and n > 0
# 1 , 32
# m > 0 and n > 0
# 1 , 31
# m > 0 and n > 0
# 1 , 30
# m > 0 and n > 0
# 1 , 29
# m > 0 and n > 0
# 1 , 28
# m > 0 and n > 0
# 1 , 27
# m > 0 and n > 0
# 1 , 26
# m > 0 and n > 0
# 1 , 25
# m > 0 and n > 0
# 1 , 24
# m > 0 and n > 0
# 1 , 23
# m > 0 and n > 0
# 1 , 22
# m > 0 and n > 0
# 1 , 21
# m > 0 and n > 0
# 1 , 20
# m > 0 and n > 0
# 1 , 19
# m > 0 and n > 0
# 1 , 18
# m > 0 and n > 0
# 1 , 17
# m > 0 and n > 0
# 1 , 16
# m > 0 and n > 0
# 1 , 15
# m > 0 and n > 0
# 1 , 14
# m > 0 and n > 0
# 1 , 13
# m > 0 and n > 0
# 1 , 12
# m > 0 and n > 0
# 1 , 11
# m > 0 and n > 0
# 1 , 10
# m > 0 and n > 0
# 1 , 9
# m > 0 and n > 0
# 1 , 8
# m > 0 and n > 0
# 1 , 7
# m > 0 and n > 0
# 1 , 6
# m > 0 and n > 0
# 1 , 5
# m > 0 and n > 0
# 1 , 4
# m > 0 and n > 0
# 1 , 3
# m > 0 and n > 0
# 1 , 2
# m > 0 and n > 0
# 1 , 1
# m > 0 and n > 0
# 1 , 0
# m > 0 and n == 0
# 0 , 1
# m == 0
# 0 , 2
# m == 0
# 0 , 3
# m == 0
# 0 , 4
# m == 0
# 0 , 5
# m == 0
# 0 , 6
# m == 0
# 0 , 7
# m == 0
# 0 , 8
# m == 0
# 0 , 9
# m == 0
# 0 , 10
# m == 0
# 0 , 11
# m == 0
# 0 , 12
# m == 0
# 0 , 13
# m == 0
# 0 , 14
# m == 0
# 0 , 15
# m == 0
# 0 , 16
# m == 0
# 0 , 17
# m == 0
# 0 , 18
# m == 0
# 0 , 19
# m == 0
# 0 , 20
# m == 0
# 0 , 21
# m == 0
# 0 , 22
# m == 0
# 0 , 23
# m == 0
# 0 , 24
# m == 0
# 0 , 25
# m == 0
# 0 , 26
# m == 0
# 0 , 27
# m == 0
# 0 , 28
# m == 0
# 0 , 29
# m == 0
# 0 , 30
# m == 0
# 0 , 31
# m == 0
# 0 , 32
# m == 0
# 0 , 33
# m == 0
# 0 , 34
# m == 0
# 0 , 35
# m == 0
# 0 , 36
# m == 0
# 0 , 37
# m == 0
# 0 , 38
# m == 0
# 0 , 39
# m == 0
# 0 , 40
# m == 0
# 0 , 41
# m == 0
# 0 , 42
# m == 0
# 0 , 43
# m == 0
# 0 , 44
# m == 0
# 0 , 45
# m == 0
# 0 , 46
# m == 0
# 0 , 47
# m == 0
# 0 , 48
# m == 0
# 0 , 49
# m == 0
# 0 , 50
# m == 0
# 0 , 51
# m == 0
# 0 , 52
# m == 0
# 0 , 53
# m == 0
# 0 , 54
# m == 0
# 0 , 55
# m == 0
# 0 , 56
# m == 0
# 0 , 57
# m == 0
# 0 , 58
# m == 0
# 0 , 59
# m == 0
# 0 , 60
# m == 0
# 0 , 61
# m == 0
# 0 , 62
# m == 0
# 0 , 63
# m == 0
# 0 , 64
# m == 0
# 0 , 65
# m == 0
# 0 , 66
# m == 0
# 0 , 67
# m == 0
# 0 , 68
# m == 0
# 0 , 69
# m == 0
# 0 , 70
# m == 0
# 0 , 71
# m == 0
# 0 , 72
# m == 0
# 0 , 73
# m == 0
# 0 , 74
# m == 0
# 0 , 75
# m == 0
# 0 , 76
# m == 0
# 0 , 77
# m == 0
# 0 , 78
# m == 0
# 0 , 79
# m == 0
# 0 , 80
# m == 0
# 0 , 81
# m == 0
# 0 , 82
# m == 0
# 0 , 83
# m == 0
# 0 , 84
# m == 0
# 0 , 85
# m == 0
# 0 , 86
# m == 0
# 0 , 87
# m == 0
# 0 , 88
# m == 0
# 0 , 89
# m == 0
# 0 , 90
# m == 0
# 0 , 91
# m == 0
# 0 , 92
# m == 0
# 0 , 93
# m == 0
# 0 , 94
# m == 0
# 0 , 95
# m == 0
# 0 , 96
# m == 0
# 0 , 97
# m == 0
# 0 , 98
# m == 0
# 0 , 99
# m == 0
# 0 , 100
# m == 0
# 0 , 101
# m == 0
# 0 , 102
# m == 0
# 0 , 103
# m == 0
# 0 , 104
# m == 0
# 0 , 105
# m == 0
# 0 , 106
# m == 0
# 0 , 107
# m == 0
# 0 , 108
# m == 0
# 0 , 109
# m == 0
# 0 , 110
# m == 0
# 0 , 111
# m == 0
# 0 , 112
# m == 0
# 0 , 113
# m == 0
# 0 , 114
# m == 0
# 0 , 115
# m == 0
# 0 , 116
# m == 0
# 0 , 117
# m == 0
# 0 , 118
# m == 0
# 0 , 119
# m == 0
# 0 , 120
# m == 0
# 0 , 121
# m == 0
# 0 , 122
# m == 0
# 0 , 123
# m == 0
# 0 , 124
# m == 0
# 125

# %% [markdown]
# If you call this function with values bigger than 4, you get a `RecursionError`.

# %%
# %%expect RecursionError
#
# ackermann(4, 1)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# 0 , 3065
# m == 0
# 0 , 3066
# m == 0
# 0 , 3067
# m == 0
# 0 , 3068
# m == 0
# 0 , 3069
# m == 0
# 0 , 3070
# m == 0
# 0 , 3071
# m == 0
# 0 , 3072
# m == 0
# 0 , 3073
# m == 0
# 0 , 3074
# m == 0
# 0 , 3075
# m == 0
# 0 , 3076
# m == 0
# 0 , 3077
# m == 0
# 0 , 3078
# m == 0
# 0 , 3079
# m == 0
# 0 , 3080
# m == 0
# 0 , 3081
# m == 0
# 0 , 3082
# m == 0
# 0 , 3083
# m == 0
# 0 , 3084
# m == 0
# 0 , 3085
# m == 0
# 0 , 3086
# m == 0
# 0 , 3087
# m == 0
# 0 , 3088
# m == 0
# 0 , 3089
# m == 0
# 0 , 3090
# m == 0
# 0 , 3091
# m == 0
# 0 , 3092
# m == 0
# 0 , 3093
# m == 0
# 0 , 3094
# m == 0
# 0 , 3095
# m == 0
# 0 , 3096
# m == 0
# 0 , 3097
# m == 0
# 0 , 3098
# m == 0
# 0 , 3099
# m == 0
# 0 , 3100
# m == 0
# 0 , 3101
# m == 0
# 0 , 3102
# m == 0
# 0 , 3103
# m == 0
# 0 , 3104
# m == 0
# 0 , 3105
# m == 0
# 0 , 3106
# m == 0
# 0 , 3107
# m == 0
# 0 , 3108
# m == 0
# 0 , 3109
# m == 0
# 0 , 3110
# m == 0
# 0 , 3111
# m == 0
# 0 , 3112
# m == 0
# 0 , 3113
# m == 0
# 0 , 3114
# m == 0
# 0 , 3115
# m == 0
# 0 , 3116
# m == 0
# 0 , 3117
# m == 0
# 0 , 3118
# m == 0
# 0 , 3119
# m == 0
# 0 , 3120
# m == 0
# 0 , 3121
# m == 0
# 0 , 3122
# m == 0
# 0 , 3123
# m == 0
# 0 , 3124
# m == 0
# 0 , 3125
# m == 0
# 0 , 3126
# m == 0
# 0 , 3127
# m == 0
# 0 , 3128
# m == 0
# 0 , 3129
# m == 0
# 0 , 3130
# m == 0
# 0 , 3131
# m == 0
# 0 , 3132
# m == 0
# 0 , 3133
# m == 0
# 0 , 3134
# m == 0
# 0 , 3135
# m == 0
# 0 , 3136
# m == 0
# 0 , 3137
# m == 0
# 0 , 3138
# m == 0
# 0 , 3139
# m == 0
# 0 , 3140
# m == 0
# 0 , 3141
# m == 0
# 0 , 3142
# m == 0
# 0 , 3143
# m == 0
# 0 , 3144
# m == 0
# 0 , 3145
# m == 0
# 0 , 3146
# m == 0
# 0 , 3147
# m == 0
# 0 , 3148
# m == 0
# 0 , 3149
# m == 0
# 0 , 3150
# m == 0
# 0 , 3151
# m == 0
# 0 , 3152
# m == 0
# 0 , 3153
# m == 0
# 0 , 3154
# m == 0
# 0 , 3155
# m == 0
# 0 , 3156
# m == 0
# 0 , 3157
# m == 0
# 0 , 3158
# m == 0
# 0 , 3159
# m == 0
# 0 , 3160
# m == 0
# 0 , 3161
# m == 0
# 0 , 3162
# m == 0
# 0 , 3163
# m == 0
# 0 , 3164
# m == 0
# 0 , 3165
# m == 0
# 0 , 3166
# m == 0
# 0 , 3167
# m == 0
# 0 , 3168
# m == 0
# 0 , 3169
# m == 0
# 0 , 3170
# m == 0
# 0 , 3171
# m == 0
# 0 , 3172
# m == 0
# 0 , 3173
# m == 0
# 0 , 3174
# m == 0
# 0 , 3175
# m == 0
# 0 , 3176
# m == 0
# 0 , 3177
# m == 0
# 0 , 3178
# m == 0
# 0 , 3179
# m == 0
# 0 , 3180
# m == 0
# 0 , 3181
# m == 0
# 0 , 3182
# m == 0
# 0 , 3183
# m == 0
# 0 , 3184
# m == 0
# 0 , 3185
# m == 0
# 0 , 3186
# m == 0
# 0 , 3187
# m == 0
# 0 , 3188
# m == 0
# 0 , 3189
# m == 0
# 0 , 3190
# m == 0
# 0 , 3191
# m == 0
# 0 , 3192
# m == 0
# 0 , 3193
# m == 0
# 0 , 3194
# m == 0
# 0 , 3195
# m == 0
# 0 , 3196
# m == 0
# 0 , 3197
# m == 0
# 0 , 3198
# m == 0
# 0 , 3199
# m == 0
# 0 , 3200
# m == 0
# 0 , 3201
# m == 0
# 0 , 3202
# m == 0
# 0 , 3203
# m == 0
# 0 , 3204
# m == 0
# 0 , 3205
# m == 0
# 0 , 3206
# m == 0
# 0 , 3207
# m == 0
# 0 , 3208
# m == 0
# 0 , 3209
# m == 0
# 0 , 3210
# m == 0
# 0 , 3211
# m == 0
# 0 , 3212
# m == 0
# 0 , 3213
# m == 0
# 0 , 3214
# m == 0
# 0 , 3215
# m == 0
# 0 , 3216
# m == 0
# 0 , 3217
# m == 0
# 0 , 3218
# m == 0
# 0 , 3219
# m == 0
# 0 , 3220
# m == 0
# 0 , 3221
# m == 0
# 0 , 3222
# m == 0
# 0 , 3223
# m == 0
# 0 , 3224
# m == 0
# 0 , 3225
# m == 0
# 0 , 3226
# m == 0
# 0 , 3227
# m == 0
# 0 , 3228
# m == 0
# 0 , 3229
# m == 0
# 0 , 3230
# m == 0
# 0 , 3231
# m == 0
# 0 , 3232
# m == 0
# 0 , 3233
# m == 0
# 0 , 3234
# m == 0
# 0 , 3235
# m == 0
# 0 , 3236
# m == 0
# 0 , 3237
# m == 0
# 0 , 3238
# m == 0
# 0 , 3239
# m == 0
# 0 , 3240
# m == 0
# 0 , 3241
# m == 0
# 0 , 3242
# m == 0
# 0 , 3243
# m == 0
# 0 , 3244
# m == 0
# 0 , 3245
# m == 0
# 0 , 3246
# m == 0
# 0 , 3247
# m == 0
# 0 , 3248
# m == 0
# 0 , 3249
# m == 0
# 0 , 3250
# m == 0
# 0 , 3251
# m == 0
# 0 , 3252
# m == 0
# 0 , 3253
# m == 0
# 0 , 3254
# m == 0
# 0 , 3255
# m == 0
# 0 , 3256
# m == 0
# 0 , 3257
# m == 0
# 0 , 3258
# m == 0
# 0 , 3259
# m == 0
# 0 , 3260
# m == 0
# 0 , 3261
# m == 0
# 0 , 3262
# m == 0
# 0 , 3263
# m == 0
# 0 , 3264
# m == 0
# 0 , 3265
# m == 0
# 0 , 3266
# m == 0
# 0 , 3267
# m == 0
# 0 , 3268
# m == 0
# 0 , 3269
# m == 0
# 0 , 3270
# m == 0
# 0 , 3271
# m == 0
# 0 , 3272
# m == 0
# 0 , 3273
# m == 0
# 0 , 3274
# m == 0
# 0 , 3275
# m == 0
# 0 , 3276
# m == 0
# 0 , 3277
# m == 0
# 0 , 3278
# m == 0
# 0 , 3279
# m == 0
# 0 , 3280
# m == 0
# 0 , 3281
# m == 0
# 0 , 3282
# m == 0
# 0 , 3283
# m == 0
# 0 , 3284
# m == 0
# 0 , 3285
# m == 0
# 0 , 3286
# m == 0
# 0 , 3287
# m == 0
# 0 , 3288
# m == 0
# 0 , 3289
# m == 0
# 0 , 3290
# m == 0
# 0 , 3291
# m == 0
# 0 , 3292
# m == 0
# 0 , 3293
# m == 0
# 0 , 3294
# m == 0
# 0 , 3295
# m == 0
# 0 , 3296
# m == 0
# 0 , 3297
# m == 0
# 0 , 3298
# m == 0
# 0 , 3299
# m == 0
# 0 , 3300
# m == 0
# 0 , 3301
# m == 0
# 0 , 3302
# m == 0
# 0 , 3303
# m == 0
# 0 , 3304
# m == 0
# 0 , 3305
# m == 0
# 0 , 3306
# m == 0
# 0 , 3307
# m == 0
# 0 , 3308
# m == 0
# 0 , 3309
# m == 0
# 0 , 3310
# m == 0
# 0 , 3311
# m == 0
# 0 , 3312
# m == 0
# 0 , 3313
# m == 0
# 0 , 3314
# m == 0
# 0 , 3315
# m == 0
# 0 , 3316
# m == 0
# 0 , 3317
# m == 0
# 0 , 3318
# m == 0
# 0 , 3319
# m == 0
# 0 , 3320
# m == 0
# 0 , 3321
# m == 0
# 0 , 3322
# m == 0
# 0 , 3323
# m == 0
# 0 , 3324
# m == 0
# 0 , 3325
# m == 0
# 0 , 3326
# m == 0
# 0 , 3327
# m == 0
# 0 , 3328
# m == 0
# 0 , 3329
# m == 0
# 0 , 3330
# m == 0
# 0 , 3331
# m == 0
# 0 , 3332
# m == 0
# 0 , 3333
# m == 0
# 0 , 3334
# m == 0
# 0 , 3335
# m == 0
# 0 , 3336
# m == 0
# 0 , 3337
# m == 0
# 0 , 3338
# m == 0
# 0 , 3339
# m == 0
# 0 , 3340
# m == 0
# 0 , 3341
# m == 0
# 0 , 3342
# m == 0
# 0 , 3343
# m == 0
# 0 , 3344
# m == 0
# 0 , 3345
# m == 0
# 0 , 3346
# m == 0
# 0 , 3347
# m == 0
# 0 , 3348
# m == 0
# 0 , 3349
# m == 0
# 0 , 3350
# m == 0
# 0 , 3351
# m == 0
# 0 , 3352
# m == 0
# 0 , 3353
# m == 0
# 0 , 3354
# m == 0
# 0 , 3355
# m == 0
# 0 , 3356
# m == 0
# 0 , 3357
# m == 0
# 0 , 3358
# m == 0
# 0 , 3359
# m == 0
# 0 , 3360
# m == 0
# 0 , 3361
# m == 0
# 0 , 3362
# m == 0
# 0 , 3363
# m == 0
# 0 , 3364
# m == 0
# 0 , 3365
# m == 0
# 0 , 3366
# m == 0
# 0 , 3367
# m == 0
# 0 , 3368
# m == 0
# 0 , 3369
# m == 0
# 0 , 3370
# m == 0
# 0 , 3371
# m == 0
# 0 , 3372
# m == 0
# 0 , 3373
# m == 0
# 0 , 3374
# m == 0
# 0 , 3375
# m == 0
# 0 , 3376
# m == 0
# 0 , 3377
# m == 0
# 0 , 3378
# m == 0
# 0 , 3379
# m == 0
# 0 , 3380
# m == 0
# 0 , 3381
# m == 0
# 0 , 3382
# m == 0
# 0 , 3383
# m == 0
# 0 , 3384
# m == 0
# 0 , 3385
# m == 0
# 0 , 3386
# m == 0
# 0 , 3387
# m == 0
# 0 , 3388
# m == 0
# 0 , 3389
# m == 0
# 0 , 3390
# m == 0
# 0 , 3391
# m == 0
# 0 , 3392
# m == 0
# 0 , 3393
# m == 0
# 0 , 3394
# m == 0
# 0 , 3395
# m == 0
# 0 , 3396
# m == 0
# 0 , 3397
# m == 0
# 0 , 3398
# m == 0
# 0 , 3399
# m == 0
# 0 , 3400
# m == 0
# 0 , 3401
# m == 0
# 0 , 3402
# m == 0
# 0 , 3403
# m == 0
# 0 , 3404
# m == 0
# 0 , 3405
# m == 0
# 0 , 3406
# m == 0
# 0 , 3407
# m == 0
# 0 , 3408
# m == 0
# 0 , 3409
# m == 0
# 0 , 3410
# m == 0
# 0 , 3411
# m == 0
# 0 , 3412
# m == 0
# 0 , 3413
# m == 0
# 0 , 3414
# m == 0
# 0 , 3415
# m == 0
# 0 , 3416
# m == 0
# 0 , 3417
# m == 0
# 0 , 3418
# m == 0
# 0 , 3419
# m == 0
# 0 , 3420
# m == 0
# 0 , 3421
# m == 0
# 0 , 3422
# m == 0
# 0 , 3423
# m == 0
# 0 , 3424
# m == 0
# 0 , 3425
# m == 0
# 0 , 3426
# m == 0
# 0 , 3427
# m == 0
# 0 , 3428
# m == 0
# 0 , 3429
# m == 0
# 0 , 3430
# m == 0
# 0 , 3431
# m == 0
# 0 , 3432
# m == 0
# 0 , 3433
# m == 0
# 0 , 3434
# m == 0
# 0 , 3435
# m == 0
# 0 , 3436
# m == 0
# 0 , 3437
# m == 0
# 0 , 3438
# m == 0
# 0 , 3439
# m == 0
# 0 , 3440
# m == 0
# 0 , 3441
# m == 0
# 0 , 3442
# m == 0
# 0 , 3443
# m == 0
# 0 , 3444
# m == 0
# 0 , 3445
# m == 0
# 0 , 3446
# m == 0
# 0 , 3447
# m == 0
# 0 , 3448
# m == 0
# 0 , 3449
# m == 0
# 0 , 3450
# m == 0
# 0 , 3451
# m == 0
# 0 , 3452
# m == 0
# 0 , 3453
# m == 0
# 0 , 3454
# m == 0
# 0 , 3455
# m == 0
# 0 , 3456
# m == 0
# 0 , 3457
# m == 0
# 0 , 3458
# m == 0
# 0 , 3459
# m == 0
# 0 , 3460
# m == 0
# 0 , 3461
# m == 0
# 0 , 3462
# m == 0
# 0 , 3463
# m == 0
# 0 , 3464
# m == 0
# 0 , 3465
# m == 0
# 0 , 3466
# m == 0
# 0 , 3467
# m == 0
# 0 , 3468
# m == 0
# 0 , 3469
# m == 0
# 0 , 3470
# m == 0
# 0 , 3471
# m == 0
# 0 , 3472
# m == 0
# 0 , 3473
# m == 0
# 0 , 3474
# m == 0
# 0 , 3475
# m == 0
# 0 , 3476
# m == 0
# 0 , 3477
# m == 0
# 0 , 3478
# m == 0
# 0 , 3479
# m == 0
# 0 , 3480
# m == 0
# 0 , 3481
# m == 0
# 0 , 3482
# m == 0
# 0 , 3483
# m == 0
# 0 , 3484
# m == 0
# 0 , 3485
# m == 0
# 0 , 3486
# m == 0
# 0 , 3487
# m == 0
# 0 , 3488
# m == 0
# 0 , 3489
# m == 0
# 0 , 3490
# m == 0
# 0 , 3491
# m == 0
# 0 , 3492
# m == 0
# 0 , 3493
# m == 0
# 0 , 3494
# m == 0
# 0 , 3495
# m == 0
# 0 , 3496
# m == 0
# 0 , 3497
# m == 0
# 0 , 3498
# m == 0
# 0 , 3499
# m == 0
# 0 , 3500
# m == 0
# 0 , 3501
# m == 0
# 0 , 3502
# m == 0
# 0 , 3503
# m == 0
# 0 , 3504
# m == 0
# 0 , 3505
# m == 0
# 0 , 3506
# m == 0
# 0 , 3507
# m == 0
# 0 , 3508
# m == 0
# 0 , 3509
# m == 0
# 0 , 3510
# m == 0
# 0 , 3511
# m == 0
# 0 , 3512
# m == 0
# 0 , 3513
# m == 0
# 0 , 3514
# m == 0
# 0 , 3515
# m == 0
# 0 , 3516
# m == 0
# 0 , 3517
# m == 0
# 0 , 3518
# m == 0
# 0 , 3519
# m == 0
# 0 , 3520
# m == 0
# 0 , 3521
# m == 0
# 0 , 3522
# m == 0
# 0 , 3523
# m == 0
# 0 , 3524
# m == 0
# 0 , 3525
# m == 0
# 0 , 3526
# m == 0
# 0 , 3527
# m == 0
# 0 , 3528
# m == 0
# 0 , 3529
# m == 0
# 0 , 3530
# m == 0
# 0 , 3531
# m == 0
# 0 , 3532
# m == 0
# 0 , 3533
# m == 0
# 0 , 3534
# m == 0
# 0 , 3535
# m == 0
# 0 , 3536
# m == 0
# 0 , 3537
# m == 0
# 0 , 3538
# m == 0
# 0 , 3539
# m == 0
# 0 , 3540
# m == 0
# 0 , 3541
# m == 0
# 0 , 3542
# m == 0
# 0 , 3543
# m == 0
# 0 , 3544
# m == 0
# 0 , 3545
# m == 0
# 0 , 3546
# m == 0
# 0 , 3547
# m == 0
# 0 , 3548
# m == 0
# 0 , 3549
# m == 0
# 0 , 3550
# m == 0
# 0 , 3551
# m == 0
# 0 , 3552
# m == 0
# 0 , 3553
# m == 0
# 0 , 3554
# m == 0
# 0 , 3555
# m == 0
# 0 , 3556
# m == 0
# 0 , 3557
# m == 0
# 0 , 3558
# m == 0
# 0 , 3559
# m == 0
# 0 , 3560
# m == 0
# 0 , 3561
# m == 0
# 0 , 3562
# m == 0
# 0 , 3563
# m == 0
# 0 , 3564
# m == 0
# 0 , 3565
# m == 0
# 0 , 3566
# m == 0
# 0 , 3567
# m == 0
# 0 , 3568
# m == 0
# 0 , 3569
# m == 0
# 0 , 3570
# m == 0
# 0 , 3571
# m == 0
# 0 , 3572
# m == 0
# 0 , 3573
# m == 0
# 0 , 3574
# m == 0
# 0 , 3575
# m == 0
# 0 , 3576
# m == 0
# 0 , 3577
# m == 0
# 0 , 3578
# m == 0
# 0 , 3579
# m == 0
# 0 , 3580
# m == 0
# 0 , 3581
# m == 0
# 0 , 3582
# m == 0
# 0 , 3583
# m == 0
# 0 , 3584
# m == 0
# 0 , 3585
# m == 0
# 0 , 3586
# m == 0
# 0 , 3587
# m == 0
# 0 , 3588
# m == 0
# 0 , 3589
# m == 0
# 0 , 3590
# m == 0
# 0 , 3591
# m == 0
# 0 , 3592
# m == 0
# 0 , 3593
# m == 0
# 0 , 3594
# m == 0
# 0 , 3595
# m == 0
# 0 , 3596
# m == 0
# 0 , 3597
# m == 0
# 0 , 3598
# m == 0
# 0 , 3599
# m == 0
# 0 , 3600
# m == 0
# 0 , 3601
# m == 0
# 0 , 3602
# m == 0
# 0 , 3603
# m == 0
# 0 , 3604
# m == 0
# 0 , 3605
# m == 0
# 0 , 3606
# m == 0
# 0 , 3607
# m == 0
# 0 , 3608
# m == 0
# 0 , 3609
# m == 0
# 0 , 3610
# m == 0
# 0 , 3611
# m == 0
# 0 , 3612
# m == 0
# 0 , 3613
# m == 0
# 0 , 3614
# m == 0
# 0 , 3615
# m == 0
# 0 , 3616
# m == 0
# 0 , 3617
# m == 0
# 0 , 3618
# m == 0
# 0 , 3619
# m == 0
# 0 , 3620
# m == 0
# 0 , 3621
# m == 0
# 0 , 3622
# m == 0
# 0 , 3623
# m == 0
# 0 , 3624
# m == 0
# 0 , 3625
# m == 0
# 0 , 3626
# m == 0
# 0 , 3627
# m == 0
# 0 , 3628
# m == 0
# 0 , 3629
# m == 0
# 0 , 3630
# m == 0
# 0 , 3631
# m == 0
# 0 , 3632
# m == 0
# 0 , 3633
# m == 0
# 0 , 3634
# m == 0
# 0 , 3635
# m == 0
# 0 , 3636
# m == 0
# 0 , 3637
# m == 0
# 0 , 3638
# m == 0
# 0 , 3639
# m == 0
# 0 , 3640
# m == 0
# 0 , 3641
# m == 0
# 0 , 3642
# m == 0
# 0 , 3643
# m == 0
# 0 , 3644
# m == 0
# 0 , 3645
# m == 0
# 0 , 3646
# m == 0
# 0 , 3647
# m == 0
# 0 , 3648
# m == 0
# 0 , 3649
# m == 0
# 0 , 3650
# m == 0
# 0 , 3651
# m == 0
# 0 , 3652
# m == 0
# 0 , 3653
# m == 0
# 0 , 3654
# m == 0
# 0 , 3655
# m == 0
# 0 , 3656
# m == 0
# 0 , 3657
# m == 0
# 0 , 3658
# m == 0
# 0 , 3659
# m == 0
# 0 , 3660
# m == 0
# 0 , 3661
# m == 0
# 0 , 3662
# m == 0
# 0 , 3663
# m == 0
# 0 , 3664
# m == 0
# 0 , 3665
# m == 0
# 0 , 3666
# m == 0
# 0 , 3667
# m == 0
# 0 , 3668
# m == 0
# 0 , 3669
# m == 0
# 0 , 3670
# m == 0
# 0 , 3671
# m == 0
# 0 , 3672
# m == 0
# 0 , 3673
# m == 0
# 0 , 3674
# m == 0
# 0 , 3675
# m == 0
# 0 , 3676
# m == 0
# 0 , 3677
# m == 0
# 0 , 3678
# m == 0
# 0 , 3679
# m == 0
# 0 , 3680
# m == 0
# 0 , 3681
# m == 0
# 0 , 3682
# m == 0
# 0 , 3683
# m == 0
# 0 , 3684
# m == 0
# 0 , 3685
# m == 0
# 0 , 3686
# m == 0
# 0 , 3687
# m == 0
# 0 , 3688
# m == 0
# 0 , 3689
# m == 0
# 0 , 3690
# m == 0
# 0 , 3691
# m == 0
# 0 , 3692
# m == 0
# 0 , 3693
# m == 0
# 0 , 3694
# m == 0
# 0 , 3695
# m == 0
# 0 , 3696
# m == 0
# 0 , 3697
# m == 0
# 0 , 3698
# m == 0
# 0 , 3699
# m == 0
# 0 , 3700
# m == 0
# 0 , 3701
# m == 0
# 0 , 3702
# m == 0
# 0 , 3703
# m == 0
# 0 , 3704
# m == 0
# 0 , 3705
# m == 0
# 0 , 3706
# m == 0
# 0 , 3707
# m == 0
# 0 , 3708
# m == 0
# 0 , 3709
# m == 0
# 0 , 3710
# m == 0
# 0 , 3711
# m == 0
# 0 , 3712
# m == 0
# 0 , 3713
# m == 0
# 0 , 3714
# m == 0
# 0 , 3715
# m == 0
# 0 , 3716
# m == 0
# 0 , 3717
# m == 0
# 0 , 3718
# m == 0
# 0 , 3719
# m == 0
# 0 , 3720
# m == 0
# 0 , 3721
# m == 0
# 0 , 3722
# m == 0
# 0 , 3723
# m == 0
# 0 , 3724
# m == 0
# 0 , 3725
# m == 0
# 0 , 3726
# m == 0
# 0 , 3727
# m == 0
# 0 , 3728
# m == 0
# 0 , 3729
# m == 0
# 0 , 3730
# m == 0
# 0 , 3731
# m == 0
# 0 , 3732
# m == 0
# 0 , 3733
# m == 0
# 0 , 3734
# m == 0
# 0 , 3735
# m == 0
# 0 , 3736
# m == 0
# 0 , 3737
# m == 0
# 0 , 3738
# m == 0
# 0 , 3739
# m == 0
# 0 , 3740
# m == 0
# 0 , 3741
# m == 0
# 0 , 3742
# m == 0
# 0 , 3743
# m == 0
# 0 , 3744
# m == 0
# 0 , 3745
# m == 0
# 0 , 3746
# m == 0
# 0 , 3747
# m == 0
# 0 , 3748
# m == 0
# 0 , 3749
# m == 0
# 0 , 3750
# m == 0
# 0 , 3751
# m == 0
# 0 , 3752
# m == 0
# 0 , 3753
# m == 0
# 0 , 3754
# m == 0
# 0 , 3755
# m == 0
# 0 , 3756
# m == 0
# 0 , 3757
# m == 0
# 0 , 3758
# m == 0
# 0 , 3759
# m == 0
# 0 , 3760
# m == 0
# 0 , 3761
# m == 0
# 0 , 3762
# m == 0
# 0 , 3763
# m == 0
# 0 , 3764
# m == 0
# 0 , 3765
# m == 0
# 0 , 3766
# m == 0
# 0 , 3767
# m == 0
# 0 , 3768
# m == 0
# 0 , 3769
# m == 0
# 0 , 3770
# m == 0
# 0 , 3771
# m == 0
# 0 , 3772
# m == 0
# 0 , 3773
# m == 0
# 0 , 3774
# m == 0
# 0 , 3775
# m == 0
# 0 , 3776
# m == 0
# 0 , 3777
# m == 0
# 0 , 3778
# m == 0
# 0 , 3779
# m == 0
# 0 , 3780
# m == 0
# 0 , 3781
# m == 0
# 0 , 3782
# m == 0
# 0 , 3783
# m == 0
# 0 , 3784
# m == 0
# 0 , 3785
# m == 0
# 0 , 3786
# m == 0
# 0 , 3787
# m == 0
# 0 , 3788
# m == 0
# 0 , 3789
# m == 0
# 0 , 3790
# m == 0
# 0 , 3791
# m == 0
# 0 , 3792
# m == 0
# 0 , 3793
# m == 0
# 0 , 3794
# m == 0
# 0 , 3795
# m == 0
# 0 , 3796
# m == 0
# 0 , 3797
# m == 0
# 0 , 3798
# m == 0
# 0 , 3799
# m == 0
# 0 , 3800
# m == 0
# 0 , 3801
# m == 0
# 0 , 3802
# m == 0
# 0 , 3803
# m == 0
# 0 , 3804
# m == 0
# 0 , 3805
# m == 0
# 0 , 3806
# m == 0
# 0 , 3807
# m == 0
# 0 , 3808
# m == 0
# 0 , 3809
# m == 0
# 0 , 3810
# m == 0
# 0 , 3811
# m == 0
# 0 , 3812
# m == 0
# 0 , 3813
# m == 0
# 0 , 3814
# m == 0
# 0 , 3815
# m == 0
# 0 , 3816
# m == 0
# 0 , 3817
# m == 0
# 0 , 3818
# m == 0
# 0 , 3819
# m == 0
# 0 , 3820
# m == 0
# 0 , 3821
# m == 0
# 0 , 3822
# m == 0
# 0 , 3823
# m == 0
# 0 , 3824
# m == 0
# 0 , 3825
# m == 0
# 0 , 3826
# m == 0
# 0 , 3827
# m == 0
# 0 , 3828
# m == 0
# 0 , 3829
# m == 0
# 0 , 3830
# m == 0
# 0 , 3831
# m == 0
# 0 , 3832
# m == 0
# 0 , 3833
# m == 0
# 0 , 3834
# m == 0
# 0 , 3835
# m == 0
# 0 , 3836
# m == 0
# 0 , 3837
# m == 0
# 0 , 3838
# m == 0
# 0 , 3839
# m == 0
# 0 , 3840
# m == 0
# 0 , 3841
# m == 0
# 0 , 3842
# m == 0
# 0 , 3843
# m == 0
# 0 , 3844
# m == 0
# 0 , 3845
# m == 0
# 0 , 3846
# m == 0
# 0 , 3847
# m == 0
# 0 , 3848
# m == 0
# 0 , 3849
# m == 0
# 0 , 3850
# m == 0
# 0 , 3851
# m == 0
# 0 , 3852
# m == 0
# 0 , 3853
# m == 0
# 0 , 3854
# m == 0
# 0 , 3855
# m == 0
# 0 , 3856
# m == 0
# 0 , 3857
# m == 0
# 0 , 3858
# m == 0
# 0 , 3859
# m == 0
# 0 , 3860
# m == 0
# 0 , 3861
# m == 0
# 0 , 3862
# m == 0
# 0 , 3863
# m == 0
# 0 , 3864
# m == 0
# 0 , 3865
# m == 0
# 0 , 3866
# m == 0
# 0 , 3867
# m == 0
# 0 , 3868
# m == 0
# 0 , 3869
# m == 0
# 0 , 3870
# m == 0
# 0 , 3871
# m == 0
# 0 , 3872
# m == 0
# 0 , 3873
# m == 0
# 0 , 3874
# m == 0
# 0 , 3875
# m == 0
# 0 , 3876
# m == 0
# 0 , 3877
# m == 0
# 0 , 3878
# m == 0
# 0 , 3879
# m == 0
# 0 , 3880
# m == 0
# 0 , 3881
# m == 0
# 0 , 3882
# m == 0
# 0 , 3883
# m == 0
# 0 , 3884
# m == 0
# 0 , 3885
# m == 0
# 0 , 3886
# m == 0
# 0 , 3887
# m == 0
# 0 , 3888
# m == 0
# 0 , 3889
# m == 0
# 0 , 3890
# m == 0
# 0 , 3891
# m == 0
# 0 , 3892
# m == 0
# 0 , 3893
# m == 0
# 0 , 3894
# m == 0
# 0 , 3895
# m == 0
# 0 , 3896
# m == 0
# 0 , 3897
# m == 0
# 0 , 3898
# m == 0
# 0 , 3899
# m == 0
# 0 , 3900
# m == 0
# 0 , 3901
# m == 0
# 0 , 3902
# m == 0
# 0 , 3903
# m == 0
# 0 , 3904
# m == 0
# 0 , 3905
# m == 0
# 0 , 3906
# m == 0
# 0 , 3907
# m == 0
# 0 , 3908
# m == 0
# 0 , 3909
# m == 0
# 0 , 3910
# m == 0
# 0 , 3911
# m == 0
# 0 , 3912
# m == 0
# 0 , 3913
# m == 0
# 0 , 3914
# m == 0
# 0 , 3915
# m == 0
# 0 , 3916
# m == 0
# 0 , 3917
# m == 0
# 0 , 3918
# m == 0
# 0 , 3919
# m == 0
# 0 , 3920
# m == 0
# 0 , 3921
# m == 0
# 0 , 3922
# m == 0
# 0 , 3923
# m == 0
# 0 , 3924
# m == 0
# 0 , 3925
# m == 0
# 0 , 3926
# m == 0
# 0 , 3927
# m == 0
# 0 , 3928
# m == 0
# 0 , 3929
# m == 0
# 0 , 3930
# m == 0
# 0 , 3931
# m == 0
# 0 , 3932
# m == 0
# 0 , 3933
# m == 0
# 0 , 3934
# m == 0
# 0 , 3935
# m == 0
# 0 , 3936
# m == 0
# 0 , 3937
# m == 0
# 0 , 3938
# m == 0
# 0 , 3939
# m == 0
# 0 , 3940
# m == 0
# 0 , 3941
# m == 0
# 0 , 3942
# m == 0
# 0 , 3943
# m == 0
# 0 , 3944
# m == 0
# 0 , 3945
# m == 0
# 0 , 3946
# m == 0
# 0 , 3947
# m == 0
# 0 , 3948
# m == 0
# 0 , 3949
# m == 0
# 0 , 3950
# m == 0
# 0 , 3951
# m == 0
# 0 , 3952
# m == 0
# 0 , 3953
# m == 0
# 0 , 3954
# m == 0
# 0 , 3955
# m == 0
# 0 , 3956
# m == 0
# 0 , 3957
# m == 0
# 0 , 3958
# m == 0
# 0 , 3959
# m == 0
# 0 , 3960
# m == 0
# 0 , 3961
# m == 0
# 0 , 3962
# m == 0
# 0 , 3963
# m == 0
# 0 , 3964
# m == 0
# 0 , 3965
# m == 0
# 0 , 3966
# m == 0
# 0 , 3967
# m == 0
# 0 , 3968
# m == 0
# 0 , 3969
# m == 0
# 0 , 3970
# m == 0
# 0 , 3971
# m == 0
# 0 , 3972
# m == 0
# 0 , 3973
# m == 0
# 0 , 3974
# m == 0
# 0 , 3975
# m == 0
# 0 , 3976
# m == 0
# 0 , 3977
# m == 0
# 0 , 3978
# m == 0
# 0 , 3979
# m == 0
# 0 , 3980
# m == 0
# 0 , 3981
# m == 0
# 0 , 3982
# m == 0
# 0 , 3983
# m == 0
# 0 , 3984
# m == 0
# 0 , 3985
# m == 0
# 0 , 3986
# m == 0
# 0 , 3987
# m == 0
# 0 , 3988
# m == 0
# 0 , 3989
# m == 0
# 0 , 3990
# m == 0
# 0 , 3991
# m == 0
# 0 , 3992
# m == 0
# 0 , 3993
# m == 0
# 0 , 3994
# m == 0
# 0 , 3995
# m == 0
# 0 , 3996
# m == 0
# 0 , 3997
# m == 0
# 0 , 3998
# m == 0
# 0 , 3999
# m == 0
# 0 , 4000
# m == 0
# 0 , 4001
# m == 0
# 0 , 4002
# m == 0
# 0 , 4003
# m == 0
# 0 , 4004
# m == 0
# 0 , 4005
# m == 0
# 0 , 4006
# m == 0
# 0 , 4007
# m == 0
# 0 , 4008
# m == 0
# 0 , 4009
# m == 0
# 0 , 4010
# m == 0
# 0 , 4011
# m == 0
# 0 , 4012
# m == 0
# 0 , 4013
# m == 0
# 0 , 4014
# m == 0
# 0 , 4015
# m == 0
# 0 , 4016
# m == 0
# 0 , 4017
# m == 0
# 0 , 4018
# m == 0
# 0 , 4019
# m == 0
# 0 , 4020
# m == 0
# 0 , 4021
# m == 0
# 0 , 4022
# m == 0
# 0 , 4023
# m == 0
# 0 , 4024
# m == 0
# 0 , 4025
# m == 0
# 0 , 4026
# m == 0
# 0 , 4027
# m == 0
# 0 , 4028
# m == 0
# 0 , 4029
# m == 0
# 0 , 4030
# m == 0
# 0 , 4031
# m == 0
# 0 , 4032
# m == 0
# 0 , 4033
# m == 0
# 0 , 4034
# m == 0
# 0 , 4035
# m == 0
# 0 , 4036
# m == 0
# 0 , 4037
# m == 0
# 0 , 4038
# m == 0
# 0 , 4039
# m == 0
# 0 , 4040
# m == 0
# 0 , 4041
# m == 0
# 0 , 4042
# m == 0
# 0 , 4043
# m == 0
# 0 , 4044
# m == 0
# 0 , 4045
# m == 0
# 0 , 4046
# m == 0
# 0 , 4047
# m == 0
# 0 , 4048
# m == 0
# 0 , 4049
# m == 0
# 0 , 4050
# m == 0
# 0 , 4051
# m == 0
# 0 , 4052
# m == 0
# 0 , 4053
# m == 0
# 0 , 4054
# m == 0
# 0 , 4055
# m == 0
# 0 , 4056
# m == 0
# 0 , 4057
# m == 0
# 0 , 4058
# m == 0
# 0 , 4059
# m == 0
# 0 , 4060
# m == 0
# 0 , 4061
# m == 0
# 0 , 4062
# m == 0
# 0 , 4063
# m == 0
# 0 , 4064
# m == 0
# 0 , 4065
# m == 0
# 0 , 4066
# m == 0
# 0 , 4067
# m == 0
# 0 , 4068
# m == 0
# 0 , 4069
# m == 0
# 0 , 4070
# m == 0
# 0 , 4071
# m == 0
# 0 , 4072
# m == 0
# 0 , 4073
# m == 0
# 0 , 4074
# m == 0
# 0 , 4075
# m == 0
# 0 , 4076
# m == 0
# 0 , 4077
# m == 0
# 0 , 4078
# m == 0
# 0 , 4079
# m == 0
# 0 , 4080
# m == 0
# 0 , 4081
# m == 0
# 0 , 4082
# m == 0
# 0 , 4083
# m == 0
# 0 , 4084
# m == 0
# 0 , 4085
# m == 0
# 0 , 4086
# m == 0
# 0 , 4087
# m == 0
# 0 , 4088
# m == 0
# 0 , 4089
# m == 0
# 0 , 4090
# m == 0
# 0 , 4091
# m == 0
# 0 , 4092
# m == 0
# 0 , 4093
# m == 0
# 0 , 4094
# m == 0
# 0 , 4095
# m == 0
# 0 , 4096
# m == 0
# 0 , 4097
# m == 0
# 0 , 4098
# m == 0
# 0 , 4099
# m == 0
# 0 , 4100
# m == 0
# 0 , 4101
# m == 0
# 0 , 4102
# m == 0
# 0 , 4103
# m == 0
# 0 , 4104
# m == 0
# 0 , 4105
# m == 0
# 0 , 4106
# m == 0
# 0 , 4107
# m == 0
# 0 , 4108
# m == 0
# 0 , 4109
# m == 0
# 0 , 4110
# m == 0
# 0 , 4111
# m == 0
# 0 , 4112
# m == 0
# 0 , 4113
# m == 0
# 0 , 4114
# m == 0
# 0 , 4115
# m == 0
# 0 , 4116
# m == 0
# 0 , 4117
# m == 0
# 0 , 4118
# m == 0
# 0 , 4119
# m == 0
# 0 , 4120
# m == 0
# 0 , 4121
# m == 0
# 0 , 4122
# m == 0
# 0 , 4123
# m == 0
# 0 , 4124
# m == 0
# 0 , 4125
# m == 0
# 0 , 4126
# m == 0
# 0 , 4127
# m == 0
# 0 , 4128
# m == 0
# 0 , 4129
# m == 0
# 0 , 4130
# m == 0
# 0 , 4131
# m == 0
# 0 , 4132
# m == 0
# 0 , 4133
# m == 0
# 0 , 4134
# m == 0
# 0 , 4135
# m == 0
# 0 , 4136
# m == 0
# 0 , 4137
# m == 0
# 0 , 4138
# m == 0
# 0 , 4139
# m == 0
# 0 , 4140
# m == 0
# 0 , 4141
# m == 0
# 0 , 4142
# m == 0
# 0 , 4143
# m == 0
# 0 , 4144
# m == 0
# 0 , 4145
# m == 0
# 0 , 4146
# m == 0
# 0 , 4147
# m == 0
# 0 , 4148
# m == 0
# 0 , 4149
# m == 0
# 0 , 4150
# m == 0
# 0 , 4151
# m == 0
# 0 , 4152
# m == 0
# 0 , 4153
# m == 0
# 0 , 4154
# m == 0
# 0 , 4155
# m == 0
# 0 , 4156
# m == 0
# 0 , 4157
# m == 0
# 0 , 4158
# m == 0
# 0 , 4159
# m == 0
# 0 , 4160
# m == 0
# 0 , 4161
# m == 0
# 0 , 4162
# m == 0
# 0 , 4163
# m == 0
# 0 , 4164
# m == 0
# 0 , 4165
# m == 0
# 0 , 4166
# m == 0
# 0 , 4167
# m == 0
# 0 , 4168
# m == 0
# 0 , 4169
# m == 0
# 0 , 4170
# m == 0
# 0 , 4171
# m == 0
# 0 , 4172
# m == 0
# 0 , 4173
# m == 0
# 0 , 4174
# m == 0
# 0 , 4175
# m == 0
# 0 , 4176
# m == 0
# 0 , 4177
# m == 0
# 0 , 4178
# m == 0
# 0 , 4179
# m == 0
# 0 , 4180
# m == 0
# 0 , 4181
# m == 0
# 0 , 4182
# m == 0
# 0 , 4183
# m == 0
# 0 , 4184
# m == 0
# 0 , 4185
# m == 0
# 0 , 4186
# m == 0
# 0 , 4187
# m == 0
# 0 , 4188
# m == 0
# 0 , 4189
# m == 0
# 0 , 4190
# m == 0
# 0 , 4191
# m == 0
# 0 , 4192
# m == 0
# 0 , 4193
# m == 0
# 0 , 4194
# m == 0
# 0 , 4195
# m == 0
# 0 , 4196
# m == 0
# 0 , 4197
# m == 0
# 0 , 4198
# m == 0
# 0 , 4199
# m == 0
# 0 , 4200
# m == 0
# 0 , 4201
# m == 0
# 0 , 4202
# m == 0
# 0 , 4203
# m == 0
# 0 , 4204
# m == 0
# 0 , 4205
# m == 0
# 0 , 4206
# m == 0
# 0 , 4207
# m == 0
# 0 , 4208
# m == 0
# 0 , 4209
# m == 0
# 0 , 4210
# m == 0
# 0 , 4211
# m == 0
# 0 , 4212
# m == 0
# 0 , 4213
# m == 0
# 0 , 4214
# m == 0
# 0 , 4215
# m == 0
# 0 , 4216
# m == 0
# 0 , 4217
# m == 0
# 0 , 4218
# m == 0
# 0 , 4219
# m == 0
# 0 , 4220
# m == 0
# 0 , 4221
# m == 0
# 0 , 4222
# m == 0
# 0 , 4223
# m == 0
# 0 , 4224
# m == 0
# 1 , 4225
# m > 0 and n > 0
# 1 , 4224
# m > 0 and n > 0
# 1 , 4223
# m > 0 and n > 0
# 1 , 4222
# m > 0 and n > 0
# 1 , 4221
# m > 0 and n > 0
# 1 , 4220
# m > 0 and n > 0
# 1 , 4219
# m > 0 and n > 0
# 1 , 4218
# m > 0 and n > 0
# 1 , 4217
# m > 0 and n > 0
# 1 , 4216
# m > 0 and n > 0
# 1 , 4215
# m > 0 and n > 0
# 1 , 4214
# m > 0 and n > 0
# 1 , 4213
# m > 0 and n > 0
# 1 , 4212
# m > 0 and n > 0
# 1 , 4211
# m > 0 and n > 0
# 1 , 4210
# m > 0 and n > 0
# 1 , 4209
# m > 0 and n > 0
# 1 , 4208
# m > 0 and n > 0
# 1 , 4207
# m > 0 and n > 0
# 1 , 4206
# m > 0 and n > 0
# 1 , 4205
# m > 0 and n > 0
# 1 , 4204
# m > 0 and n > 0
# 1 , 4203
# m > 0 and n > 0
# 1 , 4202
# m > 0 and n > 0
# 1 , 4201
# m > 0 and n > 0
# 1 , 4200
# m > 0 and n > 0
# 1 , 4199
# m > 0 and n > 0
# 1 , 4198
# m > 0 and n > 0
# 1 , 4197
# m > 0 and n > 0
# 1 , 4196
# m > 0 and n > 0
# 1 , 4195
# m > 0 and n > 0
# 1 , 4194
# m > 0 and n > 0
# 1 , 4193
# m > 0 and n > 0
# 1 , 4192
# m > 0 and n > 0
# 1 , 4191
# m > 0 and n > 0
# 1 , 4190
# m > 0 and n > 0
# 1 , 4189
# m > 0 and n > 0
# 1 , 4188
# m > 0 and n > 0
# 1 , 4187
# m > 0 and n > 0
# 1 , 4186
# m > 0 and n > 0
# 1 , 4185
# m > 0 and n > 0
# 1 , 4184
# m > 0 and n > 0
# 1 , 4183
# m > 0 and n > 0
# 1 , 4182
# m > 0 and n > 0
# 1 , 4181
# m > 0 and n > 0
# 1 , 4180
# m > 0 and n > 0
# 1 , 4179
# m > 0 and n > 0
# 1 , 4178
# m > 0 and n > 0
# 1 , 4177
# m > 0 and n > 0
# 1 , 4176
# m > 0 and n > 0
# 1 , 4175
# m > 0 and n > 0
# 1 , 4174
# m > 0 and n > 0
# 1 , 4173
# m > 0 and n > 0
# 1 , 4172
# m > 0 and n > 0
# 1 , 4171
# m > 0 and n > 0
# 1 , 4170
# m > 0 and n > 0
# 1 , 4169
# m > 0 and n > 0
# 1 , 4168
# m > 0 and n > 0
# 1 , 4167
# m > 0 and n > 0
# 1 , 4166
# m > 0 and n > 0
# 1 , 4165
# m > 0 and n > 0
# 1 , 4164
# m > 0 and n > 0
# 1 , 4163
# m > 0 and n > 0
# 1 , 4162
# m > 0 and n > 0
# 1 , 4161
# m > 0 and n > 0
# 1 , 4160
# m > 0 and n > 0
# 1 , 4159
# m > 0 and n > 0
# 1 , 4158
# m > 0 and n > 0
# 1 , 4157
# m > 0 and n > 0
# 1 , 4156
# m > 0 and n > 0
# 1 , 4155
# m > 0 and n > 0
# 1 , 4154
# m > 0 and n > 0
# 1 , 4153
# m > 0 and n > 0
# 1 , 4152
# m > 0 and n > 0
# 1 , 4151
# m > 0 and n > 0
# 1 , 4150
# m > 0 and n > 0
# 1 , 4149
# m > 0 and n > 0
# 1 , 4148
# m > 0 and n > 0
# 1 , 4147
# m > 0 and n > 0
# 1 , 4146
# m > 0 and n > 0
# 1 , 4145
# m > 0 and n > 0
# 1 , 4144
# m > 0 and n > 0
# 1 , 4143
# m > 0 and n > 0
# 1 , 4142
# m > 0 and n > 0
# 1 , 4141
# m > 0 and n > 0
# 1 , 4140
# m > 0 and n > 0
# 1 , 4139
# m > 0 and n > 0
# 1 , 4138
# m > 0 and n > 0
# 1 , 4137
# m > 0 and n > 0
# 1 , 4136
# m > 0 and n > 0
# 1 , 4135
# m > 0 and n > 0
# 1 , 4134
# m > 0 and n > 0
# 1 , 4133
# m > 0 and n > 0
# 1 , 4132
# m > 0 and n > 0
# 1 , 4131
# m > 0 and n > 0
# 1 , 4130
# m > 0 and n > 0
# 1 , 4129
# m > 0 and n > 0
# 1 , 4128
# m > 0 and n > 0
# 1 , 4127
# m > 0 and n > 0
# 1 , 4126
# m > 0 and n > 0
# 1 , 4125
# m > 0 and n > 0
# 1 , 4124
# m > 0 and n > 0
# 1 , 4123
# m > 0 and n > 0
# 1 , 4122
# m > 0 and n > 0
# 1 , 4121
# m > 0 and n > 0
# 1 , 4120
# m > 0 and n > 0
# 1 , 4119
# m > 0 and n > 0
# 1 , 4118
# m > 0 and n > 0
# 1 , 4117
# m > 0 and n > 0
# 1 , 4116
# m > 0 and n > 0
# 1 , 4115
# m > 0 and n > 0
# 1 , 4114
# m > 0 and n > 0
# 1 , 4113
# m > 0 and n > 0
# 1 , 4112
# m > 0 and n > 0
# 1 , 4111
# m > 0 and n > 0
# 1 , 4110
# m > 0 and n > 0
# 1 , 4109
# m > 0 and n > 0
# 1 , 4108
# m > 0 and n > 0
# 1 , 4107
# m > 0 and n > 0
# 1 , 4106
# m > 0 and n > 0
# 1 , 4105
# m > 0 and n > 0
# 1 , 4104
# m > 0 and n > 0
# 1 , 4103
# m > 0 and n > 0
# 1 , 4102
# m > 0 and n > 0
# 1 , 4101
# m > 0 and n > 0
# 1 , 4100
# m > 0 and n > 0
# 1 , 4099
# m > 0 and n > 0
# 1 , 4098
# m > 0 and n > 0
# 1 , 4097
# m > 0 and n > 0
# 1 , 4096
# m > 0 and n > 0
# 1 , 4095
# m > 0 and n > 0
# 1 , 4094
# m > 0 and n > 0
# 1 , 4093
# m > 0 and n > 0
# 1 , 4092
# m > 0 and n > 0
# 1 , 4091
# m > 0 and n > 0
# 1 , 4090
# m > 0 and n > 0
# 1 , 4089
# m > 0 and n > 0
# 1 , 4088
# m > 0 and n > 0
# 1 , 4087
# m > 0 and n > 0
# 1 , 4086
# m > 0 and n > 0
# 1 , 4085
# m > 0 and n > 0
# 1 , 4084
# m > 0 and n > 0
# 1 , 4083
# m > 0 and n > 0
# 1 , 4082
# m > 0 and n > 0
# 1 , 4081
# m > 0 and n > 0
# 1 , 4080
# m > 0 and n > 0
# 1 , 4079
# m > 0 and n > 0
# 1 , 4078
# m > 0 and n > 0
# 1 , 4077
# m > 0 and n > 0
# 1 , 4076
# m > 0 and n > 0
# 1 , 4075
# m > 0 and n > 0
# 1 , 4074
# m > 0 and n > 0
# 1 , 4073
# m > 0 and n > 0
# 1 , 4072
# m > 0 and n > 0
# 1 , 4071
# m > 0 and n > 0
# 1 , 4070
# m > 0 and n > 0
# 1 , 4069
# m > 0 and n > 0
# 1 , 4068
# m > 0 and n > 0
# 1 , 4067
# m > 0 and n > 0
# 1 , 4066
# m > 0 and n > 0
# 1 , 4065
# m > 0 and n > 0
# 1 , 4064
# m > 0 and n > 0
# 1 , 4063
# m > 0 and n > 0
# 1 , 4062
# m > 0 and n > 0
# 1 , 4061
# m > 0 and n > 0
# 1 , 4060
# m > 0 and n > 0
# 1 , 4059
# m > 0 and n > 0
# 1 , 4058
# m > 0 and n > 0
# 1 , 4057
# m > 0 and n > 0
# 1 , 4056
# m > 0 and n > 0
# 1 , 4055
# m > 0 and n > 0
# 1 , 4054
# m > 0 and n > 0
# 1 , 4053
# m > 0 and n > 0
# 1 , 4052
# m > 0 and n > 0
# 1 , 4051
# m > 0 and n > 0
# 1 , 4050
# m > 0 and n > 0
# 1 , 4049
# m > 0 and n > 0
# 1 , 4048
# m > 0 and n > 0
# 1 , 4047
# m > 0 and n > 0
# 1 , 4046
# m > 0 and n > 0
# 1 , 4045
# m > 0 and n > 0
# 1 , 4044
# m > 0 and n > 0
# 1 , 4043
# m > 0 and n > 0
# 1 , 4042
# m > 0 and n > 0
# 1 , 4041
# m > 0 and n > 0
# 1 , 4040
# m > 0 and n > 0
# 1 , 4039
# m > 0 and n > 0
# 1 , 4038
# m > 0 and n > 0
# 1 , 4037
# m > 0 and n > 0
# 1 , 4036
# m > 0 and n > 0
# 1 , 4035
# m > 0 and n > 0
# 1 , 4034
# m > 0 and n > 0
# 1 , 4033
# m > 0 and n > 0
# 1 , 4032
# m > 0 and n > 0
# 1 , 4031
# m > 0 and n > 0
# 1 , 4030
# m > 0 and n > 0
# 1 , 4029
# m > 0 and n > 0
# 1 , 4028
# m > 0 and n > 0
# 1 , 4027
# m > 0 and n > 0
# 1 , 4026
# m > 0 and n > 0
# 1 , 4025
# m > 0 and n > 0
# 1 , 4024
# m > 0 and n > 0
# 1 , 4023
# m > 0 and n > 0
# 1 , 4022
# m > 0 and n > 0
# 1 , 4021
# m > 0 and n > 0
# 1 , 4020
# m > 0 and n > 0
# 1 , 4019
# m > 0 and n > 0
# 1 , 4018
# m > 0 and n > 0
# 1 , 4017
# m > 0 and n > 0
# 1 , 4016
# m > 0 and n > 0
# 1 , 4015
# m > 0 and n > 0
# 1 , 4014
# m > 0 and n > 0
# 1 , 4013
# m > 0 and n > 0
# 1 , 4012
# m > 0 and n > 0
# 1 , 4011
# m > 0 and n > 0
# 1 , 4010
# m > 0 and n > 0
# 1 , 4009
# m > 0 and n > 0
# 1 , 4008
# m > 0 and n > 0
# 1 , 4007
# m > 0 and n > 0
# 1 , 4006
# m > 0 and n > 0
# 1 , 4005
# m > 0 and n > 0
# 1 , 4004
# m > 0 and n > 0
# 1 , 4003
# m > 0 and n > 0
# 1 , 4002
# m > 0 and n > 0
# 1 , 4001
# m > 0 and n > 0
# 1 , 4000
# m > 0 and n > 0
# 1 , 3999
# m > 0 and n > 0
# 1 , 3998
# m > 0 and n > 0
# 1 , 3997
# m > 0 and n > 0
# 1 , 3996
# m > 0 and n > 0
# 1 , 3995
# m > 0 and n > 0
# 1 , 3994
# m > 0 and n > 0
# 1 , 3993
# m > 0 and n > 0
# 1 , 3992
# m > 0 and n > 0
# 1 , 3991
# m > 0 and n > 0
# 1 , 3990
# m > 0 and n > 0
# 1 , 3989
# m > 0 and n > 0
# 1 , 3988
# m > 0 and n > 0
# 1 , 3987
# m > 0 and n > 0
# 1 , 3986
# m > 0 and n > 0
# 1 , 3985
# m > 0 and n > 0
# 1 , 3984
# m > 0 and n > 0
# 1 , 3983
# m > 0 and n > 0
# 1 , 3982
# m > 0 and n > 0
# 1 , 3981
# m > 0 and n > 0
# 1 , 3980
# m > 0 and n > 0
# 1 , 3979
# m > 0 and n > 0
# 1 , 3978
# m > 0 and n > 0
# 1 , 3977
# m > 0 and n > 0
# 1 , 3976
# m > 0 and n > 0
# 1 , 3975
# m > 0 and n > 0
# 1 , 3974
# m > 0 and n > 0
# 1 , 3973
# m > 0 and n > 0
# 1 , 3972
# m > 0 and n > 0
# 1 , 3971
# m > 0 and n > 0
# 1 , 3970
# m > 0 and n > 0
# 1 , 3969
# m > 0 and n > 0
# 1 , 3968
# m > 0 and n > 0
# 1 , 3967
# m > 0 and n > 0
# 1 , 3966
# m > 0 and n > 0
# 1 , 3965
# m > 0 and n > 0
# 1 , 3964
# m > 0 and n > 0
# 1 , 3963
# m > 0 and n > 0
# 1 , 3962
# m > 0 and n > 0
# 1 , 3961
# m > 0 and n > 0
# 1 , 3960
# m > 0 and n > 0
# 1 , 3959
# m > 0 and n > 0
# 1 , 3958
# m > 0 and n > 0
# 1 , 3957
# m > 0 and n > 0
# 1 , 3956
# m > 0 and n > 0
# 1 , 3955
# m > 0 and n > 0
# 1 , 3954
# m > 0 and n > 0
# 1 , 3953
# m > 0 and n > 0
# 1 , 3952
# m > 0 and n > 0
# 1 , 3951
# m > 0 and n > 0
# 1 , 3950
# m > 0 and n > 0
# 1 , 3949
# m > 0 and n > 0
# 1 , 3948
# m > 0 and n > 0
# 1 , 3947
# m > 0 and n > 0
# 1 , 3946
# m > 0 and n > 0
# 1 , 3945
# m > 0 and n > 0
# 1 , 3944
# m > 0 and n > 0
# 1 , 3943
# m > 0 and n > 0
# 1 , 3942
# m > 0 and n > 0
# 1 , 3941
# m > 0 and n > 0
# 1 , 3940
# m > 0 and n > 0
# 1 , 3939
# m > 0 and n > 0
# 1 , 3938
# m > 0 and n > 0
# 1 , 3937
# m > 0 and n > 0
# 1 , 3936
# m > 0 and n > 0
# 1 , 3935
# m > 0 and n > 0
# 1 , 3934
# m > 0 and n > 0
# 1 , 3933
# m > 0 and n > 0
# 1 , 3932
# m > 0 and n > 0
# 1 , 3931
# m > 0 and n > 0
# 1 , 3930
# m > 0 and n > 0
# 1 , 3929
# m > 0 and n > 0
# 1 , 3928
# m > 0 and n > 0
# 1 , 3927
# m > 0 and n > 0
# 1 , 3926
# m > 0 and n > 0
# 1 , 3925
# m > 0 and n > 0
# 1 , 3924
# m > 0 and n > 0
# 1 , 3923
# m > 0 and n > 0
# 1 , 3922
# m > 0 and n > 0
# 1 , 3921
# m > 0 and n > 0
# 1 , 3920
# m > 0 and n > 0
# 1 , 3919
# m > 0 and n > 0
# 1 , 3918
# m > 0 and n > 0
# 1 , 3917
# m > 0 and n > 0
# 1 , 3916
# m > 0 and n > 0
# 1 , 3915
# m > 0 and n > 0
# 1 , 3914
# m > 0 and n > 0
# 1 , 3913
# m > 0 and n > 0
# 1 , 3912
# m > 0 and n > 0
# 1 , 3911
# m > 0 and n > 0
# 1 , 3910
# m > 0 and n > 0
# 1 , 3909
# m > 0 and n > 0
# 1 , 3908
# m > 0 and n > 0
# 1 , 3907
# m > 0 and n > 0
# 1 , 3906
# m > 0 and n > 0
# 1 , 3905
# m > 0 and n > 0
# 1 , 3904
# m > 0 and n > 0
# 1 , 3903
# m > 0 and n > 0
# 1 , 3902
# m > 0 and n > 0
# 1 , 3901
# m > 0 and n > 0
# 1 , 3900
# m > 0 and n > 0
# 1 , 3899
# m > 0 and n > 0
# 1 , 3898
# m > 0 and n > 0
# 1 , 3897
# m > 0 and n > 0
# 1 , 3896
# m > 0 and n > 0
# 1 , 3895
# m > 0 and n > 0
# 1 , 3894
# m > 0 and n > 0
# 1 , 3893
# m > 0 and n > 0
# 1 , 3892
# m > 0 and n > 0
# 1 , 3891
# m > 0 and n > 0
# 1 , 3890
# m > 0 and n > 0
# 1 , 3889
# m > 0 and n > 0
# 1 , 3888
# m > 0 and n > 0
# 1 , 3887
# m > 0 and n > 0
# 1 , 3886
# m > 0 and n > 0
# 1 , 3885
# m > 0 and n > 0
# 1 , 3884
# m > 0 and n > 0
# 1 , 3883
# m > 0 and n > 0
# 1 , 3882
# m > 0 and n > 0
# 1 , 3881
# m > 0 and n > 0
# 1 , 3880
# m > 0 and n > 0
# 1 , 3879
# m > 0 and n > 0
# 1 , 3878
# m > 0 and n > 0
# 1 , 3877
# m > 0 and n > 0
# 1 , 3876
# m > 0 and n > 0
# 1 , 3875
# m > 0 and n > 0
# 1 , 3874
# m > 0 and n > 0
# 1 , 3873
# m > 0 and n > 0
# 1 , 3872
# m > 0 and n > 0
# 1 , 3871
# m > 0 and n > 0
# 1 , 3870
# m > 0 and n > 0
# 1 , 3869
# m > 0 and n > 0
# 1 , 3868
# m > 0 and n > 0
# 1 , 3867
# m > 0 and n > 0
# 1 , 3866
# m > 0 and n > 0
# 1 , 3865
# m > 0 and n > 0
# 1 , 3864
# m > 0 and n > 0
# 1 , 3863
# m > 0 and n > 0
# 1 , 3862
# m > 0 and n > 0
# 1 , 3861
# m > 0 and n > 0
# 1 , 3860
# m > 0 and n > 0
# 1 , 3859
# m > 0 and n > 0
# 1 , 3858
# m > 0 and n > 0
# 1 , 3857
# m > 0 and n > 0
# 1 , 3856
# m > 0 and n > 0
# 1 , 3855
# m > 0 and n > 0
# 1 , 3854
# m > 0 and n > 0
# 1 , 3853
# m > 0 and n > 0
# 1 , 3852
# m > 0 and n > 0
# 1 , 3851
# m > 0 and n > 0
# 1 , 3850
# m > 0 and n > 0
# 1 , 3849
# m > 0 and n > 0
# 1 , 3848
# m > 0 and n > 0
# 1 , 3847
# m > 0 and n > 0
# 1 , 3846
# m > 0 and n > 0
# 1 , 3845
# m > 0 and n > 0
# 1 , 3844
# m > 0 and n > 0
# 1 , 3843
# m > 0 and n > 0
# 1 , 3842
# m > 0 and n > 0
# 1 , 3841
# m > 0 and n > 0
# 1 , 3840
# m > 0 and n > 0
# 1 , 3839
# m > 0 and n > 0
# 1 , 3838
# m > 0 and n > 0
# 1 , 3837
# m > 0 and n > 0
# 1 , 3836
# m > 0 and n > 0
# 1 , 3835
# m > 0 and n > 0
# 1 , 3834
# m > 0 and n > 0
# 1 , 3833
# m > 0 and n > 0
# 1 , 3832
# m > 0 and n > 0
# 1 , 3831
# m > 0 and n > 0
# 1 , 3830
# m > 0 and n > 0
# 1 , 3829
# m > 0 and n > 0
# 1 , 3828
# m > 0 and n > 0
# 1 , 3827
# m > 0 and n > 0
# 1 , 3826
# m > 0 and n > 0
# 1 , 3825
# m > 0 and n > 0
# 1 , 3824
# m > 0 and n > 0
# 1 , 3823
# m > 0 and n > 0
# 1 , 3822
# m > 0 and n > 0
# 1 , 3821
# m > 0 and n > 0
# 1 , 3820
# m > 0 and n > 0
# 1 , 3819
# m > 0 and n > 0
# 1 , 3818
# m > 0 and n > 0
# 1 , 3817
# m > 0 and n > 0
# 1 , 3816
# m > 0 and n > 0
# 1 , 3815
# m > 0 and n > 0
# 1 , 3814
# m > 0 and n > 0
# 1 , 3813
# m > 0 and n > 0
# 1 , 3812
# m > 0 and n > 0
# 1 , 3811
# m > 0 and n > 0
# 1 , 3810
# m > 0 and n > 0
# 1 , 3809
# m > 0 and n > 0
# 1 , 3808
# m > 0 and n > 0
# 1 , 3807
# m > 0 and n > 0
# 1 , 3806
# m > 0 and n > 0
# 1 , 3805
# m > 0 and n > 0
# 1 , 3804
# m > 0 and n > 0
# 1 , 3803
# m > 0 and n > 0
# 1 , 3802
# m > 0 and n > 0
# 1 , 3801
# m > 0 and n > 0
# 1 , 3800
# m > 0 and n > 0
# 1 , 3799
# m > 0 and n > 0
# 1 , 3798
# m > 0 and n > 0
# 1 , 3797
# m > 0 and n > 0
# 1 , 3796
# m > 0 and n > 0
# 1 , 3795
# m > 0 and n > 0
# 1 , 3794
# m > 0 and n > 0
# 1 , 3793
# m > 0 and n > 0
# 1 , 3792
# m > 0 and n > 0
# 1 , 3791
# m > 0 and n > 0
# 1 , 3790
# m > 0 and n > 0
# 1 , 3789
# m > 0 and n > 0
# 1 , 3788
# m > 0 and n > 0
# 1 , 3787
# m > 0 and n > 0
# 1 , 3786
# m > 0 and n > 0
# 1 , 3785
# m > 0 and n > 0
# 1 , 3784
# m > 0 and n > 0
# 1 , 3783
# m > 0 and n > 0
# 1 , 3782
# m > 0 and n > 0
# 1 , 3781
# m > 0 and n > 0
# 1 , 3780
# m > 0 and n > 0
# 1 , 3779
# m > 0 and n > 0
# 1 , 3778
# m > 0 and n > 0
# 1 , 3777
# m > 0 and n > 0
# 1 , 3776
# m > 0 and n > 0
# 1 , 3775
# m > 0 and n > 0
# 1 , 3774
# m > 0 and n > 0
# 1 , 3773
# m > 0 and n > 0
# 1 , 3772
# m > 0 and n > 0
# 1 , 3771
# m > 0 and n > 0
# 1 , 3770
# m > 0 and n > 0
# 1 , 3769
# m > 0 and n > 0
# 1 , 3768
# m > 0 and n > 0
# 1 , 3767
# m > 0 and n > 0
# 1 , 3766
# m > 0 and n > 0
# 1 , 3765
# m > 0 and n > 0
# 1 , 3764
# m > 0 and n > 0
# 1 , 3763
# m > 0 and n > 0
# 1 , 3762
# m > 0 and n > 0
# 1 , 3761
# m > 0 and n > 0
# 1 , 3760
# m > 0 and n > 0
# 1 , 3759
# m > 0 and n > 0
# 1 , 3758
# m > 0 and n > 0
# 1 , 3757
# m > 0 and n > 0
# 1 , 3756
# m > 0 and n > 0
# 1 , 3755
# m > 0 and n > 0
# 1 , 3754
# m > 0 and n > 0
# 1 , 3753
# m > 0 and n > 0
# 1 , 3752
# m > 0 and n > 0
# 1 , 3751
# m > 0 and n > 0
# 1 , 3750
# m > 0 and n > 0
# 1 , 3749
# m > 0 and n > 0
# 1 , 3748
# m > 0 and n > 0
# 1 , 3747
# m > 0 and n > 0
# 1 , 3746
# m > 0 and n > 0
# 1 , 3745
# m > 0 and n > 0
# 1 , 3744
# m > 0 and n > 0
# 1 , 3743
# m > 0 and n > 0
# 1 , 3742
# m > 0 and n > 0
# 1 , 3741
# m > 0 and n > 0
# 1 , 3740
# m > 0 and n > 0
# 1 , 3739
# m > 0 and n > 0
# 1 , 3738
# m > 0 and n > 0
# 1 , 3737
# m > 0 and n > 0
# 1 , 3736
# m > 0 and n > 0
# 1 , 3735
# m > 0 and n > 0
# 1 , 3734
# m > 0 and n > 0
# 1 , 3733
# m > 0 and n > 0
# 1 , 3732
# m > 0 and n > 0
# 1 , 3731
# m > 0 and n > 0
# 1 , 3730
# m > 0 and n > 0
# 1 , 3729
# m > 0 and n > 0
# 1 , 3728
# m > 0 and n > 0
# 1 , 3727
# m > 0 and n > 0
# 1 , 3726
# m > 0 and n > 0
# 1 , 3725
# m > 0 and n > 0
# 1 , 3724
# m > 0 and n > 0
# 1 , 3723
# m > 0 and n > 0
# 1 , 3722
# m > 0 and n > 0
# 1 , 3721
# m > 0 and n > 0
# 1 , 3720
# m > 0 and n > 0
# 1 , 3719
# m > 0 and n > 0
# 1 , 3718
# m > 0 and n > 0
# 1 , 3717
# m > 0 and n > 0
# 1 , 3716
# m > 0 and n > 0
# 1 , 3715
# m > 0 and n > 0
# 1 , 3714
# m > 0 and n > 0
# 1 , 3713
# m > 0 and n > 0
# 1 , 3712
# m > 0 and n > 0
# 1 , 3711
# m > 0 and n > 0
# 1 , 3710
# m > 0 and n > 0
# 1 , 3709
# m > 0 and n > 0
# 1 , 3708
# m > 0 and n > 0
# 1 , 3707
# m > 0 and n > 0
# 1 , 3706
# m > 0 and n > 0
# 1 , 3705
# m > 0 and n > 0
# 1 , 3704
# m > 0 and n > 0
# 1 , 3703
# m > 0 and n > 0
# 1 , 3702
# m > 0 and n > 0
# 1 , 3701
# m > 0 and n > 0
# 1 , 3700
# m > 0 and n > 0
# 1 , 3699
# m > 0 and n > 0
# 1 , 3698
# m > 0 and n > 0
# 1 , 3697
# m > 0 and n > 0
# 1 , 3696
# m > 0 and n > 0
# 1 , 3695
# m > 0 and n > 0
# 1 , 3694
# m > 0 and n > 0
# 1 , 3693
# m > 0 and n > 0
# 1 , 3692
# m > 0 and n > 0
# 1 , 3691
# m > 0 and n > 0
# 1 , 3690
# m > 0 and n > 0
# 1 , 3689
# m > 0 and n > 0
# 1 , 3688
# m > 0 and n > 0
# 1 , 3687
# m > 0 and n > 0
# 1 , 3686
# m > 0 and n > 0
# 1 , 3685
# m > 0 and n > 0
# 1 , 3684
# m > 0 and n > 0
# 1 , 3683
# m > 0 and n > 0
# 1 , 3682
# m > 0 and n > 0
# 1 , 3681
# m > 0 and n > 0
# 1 , 3680
# m > 0 and n > 0
# 1 , 3679
# m > 0 and n > 0
# 1 , 3678
# m > 0 and n > 0
# 1 , 3677
# m > 0 and n > 0
# 1 , 3676
# m > 0 and n > 0
# 1 , 3675
# m > 0 and n > 0
# 1 , 3674
# m > 0 and n > 0
# 1 , 3673
# m > 0 and n > 0
# 1 , 3672
# m > 0 and n > 0
# 1 , 3671
# m > 0 and n > 0
# 1 , 3670
# m > 0 and n > 0
# 1 , 3669
# m > 0 and n > 0
# 1 , 3668
# m > 0 and n > 0
# 1 , 3667
# m > 0 and n > 0
# 1 , 3666
# m > 0 and n > 0
# 1 , 3665
# m > 0 and n > 0
# 1 , 3664
# m > 0 and n > 0
# 1 , 3663
# m > 0 and n > 0
# 1 , 3662
# m > 0 and n > 0
# 1 , 3661
# m > 0 and n > 0
# 1 , 3660
# m > 0 and n > 0
# 1 , 3659
# m > 0 and n > 0
# 1 , 3658
# m > 0 and n > 0
# 1 , 3657
# m > 0 and n > 0
# 1 , 3656
# m > 0 and n > 0
# 1 , 3655
# m > 0 and n > 0
# 1 , 3654
# m > 0 and n > 0
# 1 , 3653
# m > 0 and n > 0
# 1 , 3652
# m > 0 and n > 0
# 1 , 3651
# m > 0 and n > 0
# 1 , 3650
# m > 0 and n > 0
# 1 , 3649
# m > 0 and n > 0
# 1 , 3648
# m > 0 and n > 0
# 1 , 3647
# m > 0 and n > 0
# 1 , 3646
# m > 0 and n > 0
# 1 , 3645
# m > 0 and n > 0
# 1 , 3644
# m > 0 and n > 0
# 1 , 3643
# m > 0 and n > 0
# 1 , 3642
# m > 0 and n > 0
# 1 , 3641
# m > 0 and n > 0
# 1 , 3640
# m > 0 and n > 0
# 1 , 3639
# m > 0 and n > 0
# 1 , 3638
# m > 0 and n > 0
# 1 , 3637
# m > 0 and n > 0
# 1 , 3636
# m > 0 and n > 0
# 1 , 3635
# m > 0 and n > 0
# 1 , 3634
# m > 0 and n > 0
# 1 , 3633
# m > 0 and n > 0
# 1 , 3632
# m > 0 and n > 0
# 1 , 3631
# m > 0 and n > 0
# 1 , 3630
# m > 0 and n > 0
# 1 , 3629
# m > 0 and n > 0
# 1 , 3628
# m > 0 and n > 0
# 1 , 3627
# m > 0 and n > 0
# 1 , 3626
# m > 0 and n > 0
# 1 , 3625
# m > 0 and n > 0
# 1 , 3624
# m > 0 and n > 0
# 1 , 3623
# m > 0 and n > 0
# 1 , 3622
# m > 0 and n > 0
# 1 , 3621
# m > 0 and n > 0
# 1 , 3620
# m > 0 and n > 0
# 1 , 3619
# m > 0 and n > 0
# 1 , 3618
# m > 0 and n > 0
# 1 , 3617
# m > 0 and n > 0
# 1 , 3616
# m > 0 and n > 0
# 1 , 3615
# m > 0 and n > 0
# 1 , 3614
# m > 0 and n > 0
# 1 , 3613
# m > 0 and n > 0
# 1 , 3612
# m > 0 and n > 0
# 1 , 3611
# m > 0 and n > 0
# 1 , 3610
# m > 0 and n > 0
# 1 , 3609
# m > 0 and n > 0
# 1 , 3608
# m > 0 and n > 0
# 1 , 3607
# m > 0 and n > 0
# 1 , 3606
# m > 0 and n > 0
# 1 , 3605
# m > 0 and n > 0
# 1 , 3604
# m > 0 and n > 0
# 1 , 3603
# m > 0 and n > 0
# 1 , 3602
# m > 0 and n > 0
# 1 , 3601
# m > 0 and n > 0
# 1 , 3600
# m > 0 and n > 0
# 1 , 3599
# m > 0 and n > 0
# 1 , 3598
# m > 0 and n > 0
# 1 , 3597
# m > 0 and n > 0
# 1 , 3596
# m > 0 and n > 0
# 1 , 3595
# m > 0 and n > 0
# 1 , 3594
# m > 0 and n > 0
# 1 , 3593
# m > 0 and n > 0
# 1 , 3592
# m > 0 and n > 0
# 1 , 3591
# m > 0 and n > 0
# 1 , 3590
# m > 0 and n > 0
# 1 , 3589
# m > 0 and n > 0
# 1 , 3588
# m > 0 and n > 0
# 1 , 3587
# m > 0 and n > 0
# 1 , 3586
# m > 0 and n > 0
# 1 , 3585
# m > 0 and n > 0
# 1 , 3584
# m > 0 and n > 0
# 1 , 3583
# m > 0 and n > 0
# 1 , 3582
# m > 0 and n > 0
# 1 , 3581
# m > 0 and n > 0
# 1 , 3580
# m > 0 and n > 0
# 1 , 3579
# m > 0 and n > 0
# 1 , 3578
# m > 0 and n > 0
# 1 , 3577
# m > 0 and n > 0
# 1 , 3576
# m > 0 and n > 0
# 1 , 3575
# m > 0 and n > 0
# 1 , 3574
# m > 0 and n > 0
# 1 , 3573
# m > 0 and n > 0
# 1 , 3572
# m > 0 and n > 0
# 1 , 3571
# m > 0 and n > 0
# 1 , 3570
# m > 0 and n > 0
# 1 , 3569
# m > 0 and n > 0
# 1 , 3568
# m > 0 and n > 0
# 1 , 3567
# m > 0 and n > 0
# 1 , 3566
# m > 0 and n > 0
# 1 , 3565
# m > 0 and n > 0
# 1 , 3564
# m > 0 and n > 0
# 1 , 3563
# m > 0 and n > 0
# 1 , 3562
# m > 0 and n > 0
# 1 , 3561
# m > 0 and n > 0
# 1 , 3560
# m > 0 and n > 0
# 1 , 3559
# m > 0 and n > 0
# 1 , 3558
# m > 0 and n > 0
# 1 , 3557
# m > 0 and n > 0
# 1 , 3556
# m > 0 and n > 0
# 1 , 3555
# m > 0 and n > 0
# 1 , 3554
# m > 0 and n > 0
# 1 , 3553
# m > 0 and n > 0
# 1 , 3552
# m > 0 and n > 0
# 1 , 3551
# m > 0 and n > 0
# 1 , 3550
# m > 0 and n > 0
# 1 , 3549
# m > 0 and n > 0
# 1 , 3548
# m > 0 and n > 0
# 1 , 3547
# m > 0 and n > 0
# 1 , 3546
# m > 0 and n > 0
# 1 , 3545
# m > 0 and n > 0
# 1 , 3544
# m > 0 and n > 0
# 1 , 3543
# m > 0 and n > 0
# 1 , 3542
# m > 0 and n > 0
# 1 , 3541
# m > 0 and n > 0
# 1 , 3540
# m > 0 and n > 0
# 1 , 3539
# m > 0 and n > 0
# 1 , 3538
# m > 0 and n > 0
# 1 , 3537
# m > 0 and n > 0
# 1 , 3536
# m > 0 and n > 0
# 1 , 3535
# m > 0 and n > 0
# 1 , 3534
# m > 0 and n > 0
# 1 , 3533
# m > 0 and n > 0
# 1 , 3532
# m > 0 and n > 0
# 1 , 3531
# m > 0 and n > 0
# 1 , 3530
# m > 0 and n > 0
# 1 , 3529
# m > 0 and n > 0
# 1 , 3528
# m > 0 and n > 0
# 1 , 3527
# m > 0 and n > 0
# 1 , 3526
# m > 0 and n > 0
# 1 , 3525
# m > 0 and n > 0
# 1 , 3524
# m > 0 and n > 0
# 1 , 3523
# m > 0 and n > 0
# 1 , 3522
# m > 0 and n > 0
# 1 , 3521
# m > 0 and n > 0
# 1 , 3520
# m > 0 and n > 0
# 1 , 3519
# m > 0 and n > 0
# 1 , 3518
# m > 0 and n > 0
# 1 , 3517
# m > 0 and n > 0
# 1 , 3516
# m > 0 and n > 0
# 1 , 3515
# m > 0 and n > 0
# 1 , 3514
# m > 0 and n > 0
# 1 , 3513
# m > 0 and n > 0
# 1 , 3512
# m > 0 and n > 0
# 1 , 3511
# m > 0 and n > 0
# 1 , 3510
# m > 0 and n > 0
# 1 , 3509
# m > 0 and n > 0
# 1 , 3508
# m > 0 and n > 0
# 1 , 3507
# m > 0 and n > 0
# 1 , 3506
# m > 0 and n > 0
# 1 , 3505
# m > 0 and n > 0
# 1 , 3504
# m > 0 and n > 0
# 1 , 3503
# m > 0 and n > 0
# 1 , 3502
# m > 0 and n > 0
# 1 , 3501
# m > 0 and n > 0
# 1 , 3500
# m > 0 and n > 0
# 1 , 3499
# m > 0 and n > 0
# 1 , 3498
# m > 0 and n > 0
# 1 , 3497
# m > 0 and n > 0
# 1 , 3496
# m > 0 and n > 0
# 1 , 3495
# m > 0 and n > 0
# 1 , 3494
# m > 0 and n > 0
# 1 , 3493
# m > 0 and n > 0
# 1 , 3492
# m > 0 and n > 0
# 1 , 3491
# m > 0 and n > 0
# 1 , 3490
# m > 0 and n > 0
# 1 , 3489
# m > 0 and n > 0
# 1 , 3488
# m > 0 and n > 0
# 1 , 3487
# m > 0 and n > 0
# 1 , 3486
# m > 0 and n > 0
# 1 , 3485
# m > 0 and n > 0
# 1 , 3484
# m > 0 and n > 0
# 1 , 3483
# m > 0 and n > 0
# 1 , 3482
# m > 0 and n > 0
# 1 , 3481
# m > 0 and n > 0
# 1 , 3480
# m > 0 and n > 0
# 1 , 3479
# m > 0 and n > 0
# 1 , 3478
# m > 0 and n > 0
# 1 , 3477
# m > 0 and n > 0
# 1 , 3476
# m > 0 and n > 0
# 1 , 3475
# m > 0 and n > 0
# 1 , 3474
# m > 0 and n > 0
# 1 , 3473
# m > 0 and n > 0
# 1 , 3472
# m > 0 and n > 0
# 1 , 3471
# m > 0 and n > 0
# 1 , 3470
# m > 0 and n > 0
# 1 , 3469
# m > 0 and n > 0
# 1 , 3468
# m > 0 and n > 0
# 1 , 3467
# m > 0 and n > 0
# 1 , 3466
# m > 0 and n > 0
# 1 , 3465
# m > 0 and n > 0
# 1 , 3464
# m > 0 and n > 0
# 1 , 3463
# m > 0 and n > 0
# 1 , 3462
# m > 0 and n > 0
# 1 , 3461
# m > 0 and n > 0
# 1 , 3460
# m > 0 and n > 0
# 1 , 3459
# m > 0 and n > 0
# 1 , 3458
# m > 0 and n > 0
# 1 , 3457
# m > 0 and n > 0
# 1 , 3456
# m > 0 and n > 0
# 1 , 3455
# m > 0 and n > 0
# 1 , 3454
# m > 0 and n > 0
# 1 , 3453
# m > 0 and n > 0
# 1 , 3452
# m > 0 and n > 0
# 1 , 3451
# m > 0 and n > 0
# 1 , 3450
# m > 0 and n > 0
# 1 , 3449
# m > 0 and n > 0
# 1 , 3448
# m > 0 and n > 0
# 1 , 3447
# m > 0 and n > 0
# 1 , 3446
# m > 0 and n > 0
# 1 , 3445
# m > 0 and n > 0
# 1 , 3444
# m > 0 and n > 0
# 1 , 3443
# m > 0 and n > 0
# 1 , 3442
# m > 0 and n > 0
# 1 , 3441
# m > 0 and n > 0
# 1 , 3440
# m > 0 and n > 0
# 1 , 3439
# m > 0 and n > 0
# 1 , 3438
# m > 0 and n > 0
# 1 , 3437
# m > 0 and n > 0
# 1 , 3436
# m > 0 and n > 0
# 1 , 3435
# m > 0 and n > 0
# 1 , 3434
# m > 0 and n > 0
# 1 , 3433
# m > 0 and n > 0
# 1 , 3432
# m > 0 and n > 0
# 1 , 3431
# m > 0 and n > 0
# 1 , 3430
# m > 0 and n > 0
# 1 , 3429
# m > 0 and n > 0
# 1 , 3428
# m > 0 and n > 0
# 1 , 3427
# m > 0 and n > 0
# 1 , 3426
# m > 0 and n > 0
# 1 , 3425
# m > 0 and n > 0
# 1 , 3424
# m > 0 and n > 0
# 1 , 3423
# m > 0 and n > 0
# 1 , 3422
# m > 0 and n > 0
# 1 , 3421
# m > 0 and n > 0
# 1 , 3420
# m > 0 and n > 0
# 1 , 3419
# m > 0 and n > 0
# 1 , 3418
# m > 0 and n > 0
# 1 , 3417
# m > 0 and n > 0
# 1 , 3416
# m > 0 and n > 0
# 1 , 3415
# m > 0 and n > 0
# 1 , 3414
# m > 0 and n > 0
# 1 , 3413
# m > 0 and n > 0
# 1 , 3412
# m > 0 and n > 0
# 1 , 3411
# m > 0 and n > 0
# 1 , 3410
# m > 0 and n > 0
# 1 , 3409
# m > 0 and n > 0
# 1 , 3408
# m > 0 and n > 0
# 1 , 3407
# m > 0 and n > 0
# 1 , 3406
# m > 0 and n > 0
# 1 , 3405
# m > 0 and n > 0
# 1 , 3404
# m > 0 and n > 0
# 1 , 3403
# m > 0 and n > 0
# 1 , 3402
# m > 0 and n > 0
# 1 , 3401
# m > 0 and n > 0
# 1 , 3400
# m > 0 and n > 0
# 1 , 3399
# m > 0 and n > 0
# 1 , 3398
# m > 0 and n > 0
# 1 , 3397
# m > 0 and n > 0
# 1 , 3396
# m > 0 and n > 0
# 1 , 3395
# m > 0 and n > 0
# 1 , 3394
# m > 0 and n > 0
# 1 , 3393
# m > 0 and n > 0
# 1 , 3392
# m > 0 and n > 0
# 1 , 3391
# m > 0 and n > 0
# 1 , 3390
# m > 0 and n > 0
# 1 , 3389
# m > 0 and n > 0
# 1 , 3388
# m > 0 and n > 0
# 1 , 3387
# m > 0 and n > 0
# 1 , 3386
# m > 0 and n > 0
# 1 , 3385
# m > 0 and n > 0
# 1 , 3384
# m > 0 and n > 0
# 1 , 3383
# m > 0 and n > 0
# 1 , 3382
# m > 0 and n > 0
# 1 , 3381
# m > 0 and n > 0
# 1 , 3380
# m > 0 and n > 0
# 1 , 3379
# m > 0 and n > 0
# 1 , 3378
# m > 0 and n > 0
# 1 , 3377
# m > 0 and n > 0
# 1 , 3376
# m > 0 and n > 0
# 1 , 3375
# m > 0 and n > 0
# 1 , 3374
# m > 0 and n > 0
# 1 , 3373
# m > 0 and n > 0
# 1 , 3372
# m > 0 and n > 0
# 1 , 3371
# m > 0 and n > 0
# 1 , 3370
# m > 0 and n > 0
# 1 , 3369
# m > 0 and n > 0
# 1 , 3368
# m > 0 and n > 0
# 1 , 3367
# m > 0 and n > 0
# 1 , 3366
# m > 0 and n > 0
# 1 , 3365
# m > 0 and n > 0
# 1 , 3364
# m > 0 and n > 0
# 1 , 3363
# m > 0 and n > 0
# 1 , 3362
# m > 0 and n > 0
# 1 , 3361
# m > 0 and n > 0
# 1 , 3360
# m > 0 and n > 0
# 1 , 3359
# m > 0 and n > 0
# 1 , 3358
# m > 0 and n > 0
# 1 , 3357
# m > 0 and n > 0
# 1 , 3356
# m > 0 and n > 0
# 1 , 3355
# m > 0 and n > 0
# 1 , 3354
# m > 0 and n > 0
# 1 , 3353
# m > 0 and n > 0
# 1 , 3352
# m > 0 and n > 0
# 1 , 3351
# m > 0 and n > 0
# 1 , 3350
# m > 0 and n > 0
# 1 , 3349
# m > 0 and n > 0
# 1 , 3348
# m > 0 and n > 0
# 1 , 3347
# m > 0 and n > 0
# 1 , 3346
# m > 0 and n > 0
# 1 , 3345
# m > 0 and n > 0
# 1 , 3344
# m > 0 and n > 0
# 1 , 3343
# m > 0 and n > 0
# 1 , 3342
# m > 0 and n > 0
# 1 , 3341
# m > 0 and n > 0
# 1 , 3340
# m > 0 and n > 0
# 1 , 3339
# m > 0 and n > 0
# 1 , 3338
# m > 0 and n > 0
# 1 , 3337
# m > 0 and n > 0
# 1 , 3336
# m > 0 and n > 0
# 1 , 3335
# m > 0 and n > 0
# 1 , 3334
# m > 0 and n > 0
# 1 , 3333
# m > 0 and n > 0
# 1 , 3332
# m > 0 and n > 0
# 1 , 3331
# m > 0 and n > 0
# 1 , 3330
# m > 0 and n > 0
# 1 , 3329
# m > 0 and n > 0
# 1 , 3328
# m > 0 and n > 0
# 1 , 3327
# m > 0 and n > 0
# 1 , 3326
# m > 0 and n > 0
# 1 , 3325
# m > 0 and n > 0
# 1 , 3324
# m > 0 and n > 0
# 1 , 3323
# m > 0 and n > 0
# 1 , 3322
# m > 0 and n > 0
# 1 , 3321
# m > 0 and n > 0
# 1 , 3320
# m > 0 and n > 0
# 1 , 3319
# m > 0 and n > 0
# 1 , 3318
# m > 0 and n > 0
# 1 , 3317
# m > 0 and n > 0
# 1 , 3316
# m > 0 and n > 0
# 1 , 3315
# m > 0 and n > 0
# 1 , 3314
# m > 0 and n > 0
# 1 , 3313
# m > 0 and n > 0
# 1 , 3312
# m > 0 and n > 0
# 1 , 3311
# m > 0 and n > 0
# 1 , 3310
# m > 0 and n > 0
# 1 , 3309
# m > 0 and n > 0
# 1 , 3308
# m > 0 and n > 0
# 1 , 3307
# m > 0 and n > 0
# 1 , 3306
# m > 0 and n > 0
# 1 , 3305
# m > 0 and n > 0
# 1 , 3304
# m > 0 and n > 0
# 1 , 3303
# m > 0 and n > 0
# 1 , 3302
# m > 0 and n > 0
# 1 , 3301
# m > 0 and n > 0
# 1 , 3300
# m > 0 and n > 0
# 1 , 3299
# m > 0 and n > 0
# 1 , 3298
# m > 0 and n > 0
# 1 , 3297
# m > 0 and n > 0
# 1 , 3296
# m > 0 and n > 0
# 1 , 3295
# m > 0 and n > 0
# 1 , 3294
# m > 0 and n > 0
# 1 , 3293
# m > 0 and n > 0
# 1 , 3292
# m > 0 and n > 0
# 1 , 3291
# m > 0 and n > 0
# 1 , 3290
# m > 0 and n > 0
# 1 , 3289
# m > 0 and n > 0
# 1 , 3288
# m > 0 and n > 0
# 1 , 3287
# m > 0 and n > 0
# 1 , 3286
# m > 0 and n > 0
# 1 , 3285
# m > 0 and n > 0
# 1 , 3284
# m > 0 and n > 0
# 1 , 3283
# m > 0 and n > 0
# 1 , 3282
# m > 0 and n > 0
# 1 , 3281
# m > 0 and n > 0
# 1 , 3280
# m > 0 and n > 0
# 1 , 3279
# m > 0 and n > 0
# 1 , 3278
# m > 0 and n > 0
# 1 , 3277
# m > 0 and n > 0
# 1 , 3276
# m > 0 and n > 0
# 1 , 3275
# m > 0 and n > 0
# 1 , 3274
# m > 0 and n > 0
# 1 , 3273
# m > 0 and n > 0
# 1 , 3272
# m > 0 and n > 0
# 1 , 3271
# m > 0 and n > 0
# 1 , 3270
# m > 0 and n > 0
# 1 , 3269
# m > 0 and n > 0
# 1 , 3268
# m > 0 and n > 0
# 1 , 3267
# m > 0 and n > 0
# 1 , 3266
# m > 0 and n > 0
# 1 , 3265
# m > 0 and n > 0
# 1 , 3264
# m > 0 and n > 0
# 1 , 3263
# m > 0 and n > 0
# 1 , 3262
# m > 0 and n > 0
# 1 , 3261
# m > 0 and n > 0
# 1 , 3260
# m > 0 and n > 0
# 1 , 3259
# m > 0 and n > 0
# 1 , 3258
# m > 0 and n > 0
# 1 , 3257
# m > 0 and n > 0
# 1 , 3256
# m > 0 and n > 0
# 1 , 3255
# m > 0 and n > 0
# 1 , 3254
# m > 0 and n > 0
# 1 , 3253
# m > 0 and n > 0
# 1 , 3252
# m > 0 and n > 0
# 1 , 3251
# m > 0 and n > 0
# 1 , 3250
# m > 0 and n > 0
# 1 , 3249
# m > 0 and n > 0
# 1 , 3248
# m > 0 and n > 0
# 1 , 3247
# m > 0 and n > 0
# 1 , 3246
# m > 0 and n > 0
# 1 , 3245
# m > 0 and n > 0
# 1 , 3244
# m > 0 and n > 0
# 1 , 3243
# m > 0 and n > 0
# 1 , 3242
# m > 0 and n > 0
# 1 , 3241
# m > 0 and n > 0
# 1 , 3240
# m > 0 and n > 0
# 1 , 3239
# m > 0 and n > 0
# 1 , 3238
# m > 0 and n > 0
# 1 , 3237
# m > 0 and n > 0
# 1 , 3236
# m > 0 and n > 0
# 1 , 3235
# m > 0 and n > 0
# 1 , 3234
# m > 0 and n > 0
# 1 , 3233
# m > 0 and n > 0
# 1 , 3232
# m > 0 and n > 0
# 1 , 3231
# m > 0 and n > 0
# 1 , 3230
# m > 0 and n > 0
# 1 , 3229
# m > 0 and n > 0
# 1 , 3228
# m > 0 and n > 0
# 1 , 3227
# m > 0 and n > 0
# 1 , 3226
# m > 0 and n > 0
# 1 , 3225
# m > 0 and n > 0
# 1 , 3224
# m > 0 and n > 0
# 1 , 3223
# m > 0 and n > 0
# 1 , 3222
# m > 0 and n > 0
# 1 , 3221
# m > 0 and n > 0
# 1 , 3220
# m > 0 and n > 0
# 1 , 3219
# m > 0 and n > 0
# 1 , 3218
# m > 0 and n > 0
# 1 , 3217
# m > 0 and n > 0
# 1 , 3216
# m > 0 and n > 0
# 1 , 3215
# m > 0 and n > 0
# 1 , 3214
# m > 0 and n > 0
# 1 , 3213
# m > 0 and n > 0
# 1 , 3212
# m > 0 and n > 0
# 1 , 3211
# m > 0 and n > 0
# 1 , 3210
# m > 0 and n > 0
# 1 , 3209
# m > 0 and n > 0
# 1 , 3208
# m > 0 and n > 0
# 1 , 3207
# m > 0 and n > 0
# 1 , 3206
# m > 0 and n > 0
# 1 , 3205
# m > 0 and n > 0
# 1 , 3204
# m > 0 and n > 0
# 1 , 3203
# m > 0 and n > 0
# 1 , 3202
# m > 0 and n > 0
# 1 , 3201
# m > 0 and n > 0
# 1 , 3200
# m > 0 and n > 0
# 1 , 3199
# m > 0 and n > 0
# 1 , 3198
# m > 0 and n > 0
# 1 , 3197
# m > 0 and n > 0
# 1 , 3196
# m > 0 and n > 0
# 1 , 3195
# m > 0 and n > 0
# 1 , 3194
# m > 0 and n > 0
# 1 , 3193
# m > 0 and n > 0
# 1 , 3192
# m > 0 and n > 0
# 1 , 3191
# m > 0 and n > 0
# 1 , 3190
# m > 0 and n > 0
# 1 , 3189
# m > 0 and n > 0
# 1 , 3188
# m > 0 and n > 0
# 1 , 3187
# m > 0 and n > 0
# 1 , 3186
# m > 0 and n > 0
# 1 , 3185
# m > 0 and n > 0
# 1 , 3184
# m > 0 and n > 0
# 1 , 3183
# m > 0 and n > 0
# 1 , 3182
# m > 0 and n > 0
# 1 , 3181
# m > 0 and n > 0
# 1 , 3180
# m > 0 and n > 0
# 1 , 3179
# m > 0 and n > 0
# 1 , 3178
# m > 0 and n > 0
# 1 , 3177
# m > 0 and n > 0
# 1 , 3176
# m > 0 and n > 0
# 1 , 3175
# m > 0 and n > 0
# 1 , 3174
# m > 0 and n > 0
# 1 , 3173
# m > 0 and n > 0
# 1 , 3172
# m > 0 and n > 0
# 1 , 3171
# m > 0 and n > 0
# 1 , 3170
# m > 0 and n > 0
# 1 , 3169
# m > 0 and n > 0
# 1 , 3168
# m > 0 and n > 0
# 1 , 3167
# m > 0 and n > 0
# 1 , 3166
# m > 0 and n > 0
# 1 , 3165
# m > 0 and n > 0
# 1 , 3164
# m > 0 and n > 0
# 1 , 3163
# m > 0 and n > 0
# 1 , 3162
# m > 0 and n > 0
# 1 , 3161
# m > 0 and n > 0
# 1 , 3160
# m > 0 and n > 0
# 1 , 3159
# m > 0 and n > 0
# 1 , 3158
# m > 0 and n > 0
# 1 , 3157
# m > 0 and n > 0
# 1 , 3156
# m > 0 and n > 0
# 1 , 3155
# m > 0 and n > 0
# 1 , 3154
# m > 0 and n > 0
# 1 , 3153
# m > 0 and n > 0
# 1 , 3152
# m > 0 and n > 0
# 1 , 3151
# m > 0 and n > 0
# 1 , 3150
# m > 0 and n > 0
# 1 , 3149
# m > 0 and n > 0
# 1 , 3148
# m > 0 and n > 0
# 1 , 3147
# m > 0 and n > 0
# 1 , 3146
# m > 0 and n > 0
# 1 , 3145
# m > 0 and n > 0
# 1 , 3144
# m > 0 and n > 0
# 1 , 3143
# m > 0 and n > 0
# 1 , 3142
# m > 0 and n > 0
# 1 , 3141
# m > 0 and n > 0
# 1 , 3140
# m > 0 and n > 0
# 1 , 3139
# m > 0 and n > 0
# 1 , 3138
# m > 0 and n > 0
# 1 , 3137
# m > 0 and n > 0
# 1 , 3136
# m > 0 and n > 0
# 1 , 3135
# m > 0 and n > 0
# 1 , 3134
# m > 0 and n > 0
# 1 , 3133
# m > 0 and n > 0
# 1 , 3132
# m > 0 and n > 0
# 1 , 3131
# m > 0 and n > 0
# 1 , 3130
# m > 0 and n > 0
# 1 , 3129
# m > 0 and n > 0
# 1 , 3128
# m > 0 and n > 0
# 1 , 3127
# m > 0 and n > 0
# 1 , 3126
# m > 0 and n > 0
# 1 , 3125
# m > 0 and n > 0
# 1 , 3124
# m > 0 and n > 0
# 1 , 3123
# m > 0 and n > 0
# 1 , 3122
# m > 0 and n > 0
# 1 , 3121
# m > 0 and n > 0
# 1 , 3120
# m > 0 and n > 0
# 1 , 3119
# m > 0 and n > 0
# 1 , 3118
# m > 0 and n > 0
# 1 , 3117
# m > 0 and n > 0
# 1 , 3116
# m > 0 and n > 0
# 1 , 3115
# m > 0 and n > 0
# 1 , 3114
# m > 0 and n > 0
# 1 , 3113
# m > 0 and n > 0
# 1 , 3112
# m > 0 and n > 0
# 1 , 3111
# m > 0 and n > 0
# 1 , 3110
# m > 0 and n > 0
# 1 , 3109
# m > 0 and n > 0
# 1 , 3108
# m > 0 and n > 0
# 1 , 3107
# m > 0 and n > 0
# 1 , 3106
# m > 0 and n > 0
# 1 , 3105
# m > 0 and n > 0
# 1 , 3104
# m > 0 and n > 0
# 1 , 3103
# m > 0 and n > 0
# 1 , 3102
# m > 0 and n > 0
# 1 , 3101
# m > 0 and n > 0
# 1 , 3100
# m > 0 and n > 0
# 1 , 3099
# m > 0 and n > 0
# 1 , 3098
# m > 0 and n > 0
# 1 , 3097
# m > 0 and n > 0
# 1 , 3096
# m > 0 and n > 0
# 1 , 3095
# m > 0 and n > 0
# 1 , 3094
# m > 0 and n > 0
# 1 , 3093
# m > 0 and n > 0
# 1 , 3092
# m > 0 and n > 0
# 1 , 3091
# m > 0 and n > 0
# 1 , 3090
# m > 0 and n > 0
# 1 , 3089
# m > 0 and n > 0
# 1 , 3088
# m > 0 and n > 0
# 1 , 3087
# m > 0 and n > 0
# 1 , 3086
# m > 0 and n > 0
# 1 , 3085
# m > 0 and n > 0
# 1 , 3084
# m > 0 and n > 0
# 1 , 3083
# m > 0 and n > 0
# 1 , 3082
# m > 0 and n > 0
# 1 , 3081
# m > 0 and n > 0
# 1 , 3080
# m > 0 and n > 0
# 1 , 3079
# m > 0 and n > 0
# 1 , 3078
# m > 0 and n > 0
# 1 , 3077
# m > 0 and n > 0
# 1 , 3076
# m > 0 and n > 0
# 1 , 3075
# m > 0 and n > 0
# 1 , 3074
# m > 0 and n > 0
# 1 , 3073
# m > 0 and n > 0
# 1 , 3072
# m > 0 and n > 0
# 1 , 3071
# m > 0 and n > 0
# 1 , 3070
# m > 0 and n > 0
# 1 , 3069
# m > 0 and n > 0
# 1 , 3068
# m > 0 and n > 0
# 1 , 3067
# m > 0 and n > 0
# 1 , 3066
# m > 0 and n > 0
# 1 , 3065
# m > 0 and n > 0
# 1 , 3064
# m > 0 and n > 0
# 1 , 3063
# m > 0 and n > 0
# 1 , 3062
# m > 0 and n > 0
# 1 , 3061
# m > 0 and n > 0
# 1 , 3060
# m > 0 and n > 0
# 1 , 3059
# m > 0 and n > 0
# 1 , 3058
# m > 0 and n > 0
# 1 , 3057
# m > 0 and n > 0
# 1 , 3056
# m > 0 and n > 0
# 1 , 3055
# m > 0 and n > 0
# 1 , 3054
# m > 0 and n > 0
# 1 , 3053
# m > 0 and n > 0
# 1 , 3052
# m > 0 and n > 0
# 1 , 3051
# m > 0 and n > 0
# ...
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2938)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2937)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2936)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2935)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2934)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2933)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2932)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2931)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2930)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2929)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2928)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2927)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2926)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2925)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2924)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2923)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2922)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2921)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2920)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2919)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2918)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2917)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2916)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2915)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2914)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2913)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2912)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2911)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2910)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2909)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2908)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2907)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2906)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2905)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2904)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2903)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2902)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2901)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2900)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2899)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2898)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2897)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2896)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2895)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2894)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2893)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2892)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2891)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2890)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2889)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2888)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2887)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2886)
#      15   else:
#      16     print("m > 0 and n > 0")
# ---> 17     return ackermann(m - 1, ackermann(m, n - 1))
#         global ackermann = <function ackermann at 0x799829fa1940>
#         m = undefined
#         n = undefined
#
# /tmp/ipykernel_1811/3254878243.py in ackermann(m=1, n=2885)
#       6   m and n are positive integers.
#       7   """
# ----> 8   print(m, ",", n)
#         global print = undefined
#         m = undefined
#         n = undefined
#       9   if m == 0:
#      10     print("m == 0")
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/iostream.py in write(self=<ipykernel.iostream.OutStream object>, string='1')
#     548         else:
#     549
# --> 550             is_child = not self._is_master_process()
#         is_child = undefined
#         self._is_master_process = undefined
#     551             # only touch the buffer in the IO thread to avoid races
#     552             with self._buffer_lock:
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/iostream.py in _is_master_process(self=<ipykernel.iostream.OutStream object>)
#     436
#     437     def _is_master_process(self):
# --> 438         return os.getpid() == self._master_pid
#         global os.getpid = <built-in function getpid>
#         self._master_pid = undefined
#     439
#     440     def set_parent(self, parent):
#
# KeyboardInterrupt:

# %% [markdown]
# To see why, add a print statement to the beginning of the function to display the values of the parameters, and then run the examples again.

# %% [markdown]
# ### Exercise
#
# A number, $a$, is a power of $b$ if it is divisible by $b$ and $a/b$ is
# a power of $b$. Write a function called `is_power` that takes parameters
# `a` and `b` and returns `True` if `a` is a power of `b`. Note: you will
# have to think about the base case.

# %%
# Solution goes here

def is_power(a, b):
  """" Returns True if a is a power of b.

  a and b are positive integers.
  """

  if a == b or a == 1:
    return True
  elif b == 1:
    return False
  elif a % b != 0:
    return False
  else:
    return is_power(a / b, b)

# %% [markdown]
# You can use these examples to test your function.

# %%
is_power(65536, 2)   # should be True
# Out:
# True

# %%
is_power(27, 3)  # should be True
# Out:
# True

# %%
is_power(24, 2)  # should be False
# Out:
# False

# %%
is_power(1, 17)   # should be True
# Out:
# True

# %%
is_power(10, 1)   # should be False
# Out:
# False

# %% [markdown]
# I asked the VA for a solution using logarithm. Sounded useful at first, but seems more complicated.

# %%
import math

def is_power_logarithm(a, b):
    # According to the problem description, a and b are positive integers.

    # Handle the special case where a is 1. Any positive integer b raised to the power of 0 is 1.
    # So, 1 is a power of any positive integer b.
    if a == 1:
        return True

    # If a > 1 and b is 1, a cannot be a power of b (unless a was also 1, handled above).
    # For example, 1^k will always be 1, so 2 is not a power of 1.
    if b == 1:
        return False

    # Calculate log_b(a). Python's math.log(x, base) directly computes this.
    try:
        exponent = math.log(a, b)
    except ValueError:
        # This catch is mostly for robustness if inputs were not guaranteed positive
        # For positive integers, log(a,b) should not raise ValueError unless b=1 for example.
        return False

    # Due to floating-point arithmetic, the result might not be exactly an integer.
    # We check if the exponent is very close to an integer.
    epsilon = 1e-9 # A small tolerance for floating point comparisons
    return abs(exponent - round(exponent)) < epsilon

# %%
print(f"is_power_logarithm(65536, 2): {is_power_logarithm(65536, 2)}") # should be True
print(f"is_power_logarithm(27, 3): {is_power_logarithm(27, 3)}")    # should be True
print(f"is_power_logarithm(24, 2): {is_power_logarithm(24, 2)}")    # should be False
print(f"is_power_logarithm(1, 17): {is_power_logarithm(1, 17)}")    # should be True (mathematically correct)
# Out:
# is_power_logarithm(65536, 2): True
# is_power_logarithm(27, 3): True
# is_power_logarithm(24, 2): False
# is_power_logarithm(1, 17): True

# %% [markdown]
# ### Exercise
#
# The greatest common divisor (GCD) of $a$ and $b$ is the largest number
# that divides both of them with no remainder.
#
# One way to find the GCD of two numbers is based on the observation that
# if $r$ is the remainder when $a$ is divided by $b$, then $gcd(a,
# b) = gcd(b, r)$. As a base case, we can use $gcd(a, 0) = a$.
#
# Write a function called `gcd` that takes parameters `a` and `b` and
# returns their greatest common divisor.

# %%
# Solution goes here

def gcd(a, b):
  """" Returns the greatest common divisor of a and b.

  a and b are positive integers.
  """
  if b == 0:
    return a
  else:
    r = a % b
    return gcd(b, r)

# %% [markdown]
# You can use these examples to test your function.

# %%
gcd(12, 8)    # should be 4
# Out:
# 12 8 4
# 8 4 0
# 4

# %%
gcd(13, 17)   # should be 1
# Out:
# 13 17 13
# 17 13 4
# 13 4 1
# 4 1 0
# 1

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
